# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Opt
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Opt

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Opt'

# %%
# importing pandas libraries and
# glob module
import pandas as pd

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['2022', '2021']

# %%
# Function to recursively find Excel files in a folder and its subfolders
def find_excel_files(root_dir):
    excel_files = []
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.xlsx'):
                excel_files.append(os.path.join(root, file))
    return excel_files
# Find all Excel files in the specified folder and its subfolders
excel_files = find_excel_files(dir_path)
print(excel_files)
# Out:
# ['/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_13.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_14.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_13.x ...

# %%
#df1 = pd.read_excel('/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_1.xlsx')
#df1.head()

# %%
#df1.tail()

# %%
import pickle

# Try to open the file for reading
try:
    with open("merged_files.pkl", "rb") as file:
        merged_files = pickle.load(file)
    print("Existing 'merged_files.pkl' file found and loaded.")
except FileNotFoundError:
    # If the file doesn't exist, create an empty list
    merged_files = []
    with open("merged_files.pkl", "wb") as file:
        pickle.dump(merged_files, file)
    print("New 'merged_files.pkl' file created.")

# Print or use the 'merged_files' list as needed
print("merged_files:", merged_files)
# Out:
# Existing 'merged_files.pkl' file found and loaded.
# merged_files: ['/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_13.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_14.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_op ...

# %%
import pandas as pd
import os

# Check if "Opt.csv" file exists
if os.path.isfile("Opt.csv"):
    # If the file exists, load it into a DataFrame
    df = pd.read_csv("Opt.csv")

    # Define df_Opt by selecting specific columns
    df_Opt = df[["Timestamp", "Amount USD (Excel)"]]
else:
    # If the file doesn't exist, initialize an empty DataFrame
    df_Opt = pd.DataFrame()

# Now, you can use df_Opt in your script, whether it's loaded from the file or empty.
df_Opt
# Out:
#                     Timestamp  Amount USD (Excel)
# 0         2022-02-04 12:45:58            0.000000
# 1         2022-02-06 01:41:30            0.000000
# 2         2022-02-02 09:34:18            0.000000
# 3         2022-02-02 09:34:18         1070.680722
# 4         2022-02-03 09:14:12            0.000000
# ...                       ...                 ...
# 17428300  2022-06-02 22:23:01          151.039205
# 17428301  2022-06-02 07:33:25            0.999306
# 17428302  2022-06-02 07:33:25            0.999778
# 17428303  2022-06-02 23:10:39           19.596420
# 17428304  2022-06-02 08:33:53          589.177835
#
# [17428305 rows x 2 columns]

# %%
# Continue or Update
import pandas as pd
from tqdm import tqdm
import pickle

# Load the previously saved merged_files list
with open("merged_files.pkl", "rb") as file:
    merged_files = pickle.load(file)
print(merged_files)


# Get the list of remaining files by excluding already merged ones
remaining_files = [file for file in excel_files if file not in merged_files]
print(remaining_files)
# Create a progress bar using tqdm
with tqdm(total=len(remaining_files), desc="Merging Excel Files") as pbar:
    for excel_file in remaining_files:
        df_temp = pd.read_excel(excel_file, engine='openpyxl')
        df_temp = df_temp[["Timestamp", "Amount USD (Excel)"]]
        df_Opt = pd.concat([df_Opt, df_temp], ignore_index=True, sort=False)

        # Update the lists of merged and remaining files
        merged_files.append(excel_file)
        with open("merged_files.pkl", "wb") as file:
          pickle.dump(merged_files, file)
        df_Opt.to_csv("Opt.csv", index=False)
        # Update the progress bar
        pbar.update(1)

# Save the final merged DataFrame to a CSV file
print("Merging completed. Progress saved.")
# Out:
# ['/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/February/uniswap_opt_2022_02_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/March/uniswap_opt_2022_03_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_13.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_14.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/April/uniswap_opt_2022_04_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/May/uniswap_opt_2022_05_13.x ...
# ['/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_32.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_21.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_36.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_12.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_7.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_16.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_2.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_5.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_37.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_6.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_11.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_8.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_15.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_13.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_3.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_9.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_4.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_30.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_33.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_17.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_35.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_10.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_31.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_23.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_22.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_14.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_34.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_1.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_18.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/uniswap_opt_2022_06_22_fix.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/uniswap_opt_2022_06_21_fix.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/uniswap_opt_2022_06_20_fix.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_20_fix.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_20.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_19.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_24.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_25.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/uniswap_opt_2022_06_26.xlsx', '/content/drive/MyDrive/all_pool_uniswap/Optimism/2021_2022/2022/June/._uniswap_opt_2022_06_26.xlsx', '/content/drive/MyDriv ...
# Merging Excel Files:   0%|          | 0/133 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-22-3f945981db14> in <cell line: 16>()
#      16 with tqdm(total=len(remaining_files), desc="Merging Excel Files") as pbar:
#      17     for excel_file in remaining_files:
# ---> 18         df_temp = pd.read_excel(excel_file, engine='openpyxl')
#      19         df_temp = df_temp[["Timestamp", "Amount USD (Excel)"]]
#      20         df_Opt = pd.concat([df_Opt, df_temp], ignore_index=True, sort=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1693         self.storage_options = storage_options
#    1694
# -> 1695         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1696
#    1697     def __fspath__(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     555         """
#     556         import_optional_dependency("openpyxl")
# --> 557         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     558
#     559     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer, storage_options)
#     543             self.handles.handle.seek(0)
#     544             try:
# --> 545                 self.book = self.load_workbook(self.handles.handle)
#     546             except Exception:
#     547                 self.close()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in load_workbook(self, filepath_or_buffer)
#     566         from openpyxl import load_workbook
#     567
# --> 568         return load_workbook(
#     569             filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570         )
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     342
#     343     """
# --> 344     reader = ExcelReader(filename, read_only, keep_vba,
#     345                          data_only, keep_links, rich_text)
#     346     reader.read()
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121     def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122                  data_only=False, keep_links=True, rich_text=False):
# --> 123         self.archive = _validate_archive(fn)
#     124         self.valid_files = self.archive.namelist()
#     125         self.read_only = read_only
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in _validate_archive(filename)
#      93             raise InvalidFileException(msg)
#      94
# ---> 95     archive = ZipFile(filename, 'r')
#      96     return archive
#      97
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
#    1268             if mode == 'r':
# -> 1269                 self._RealGetContents()
#    1270             elif mode in ('w', 'x'):
#    1271                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.10/zipfile.py in _RealGetContents(self)
#    1334             raise BadZipFile("File is not a zip file")
#    1335         if not endrec:
# -> 1336             raise BadZipFile("File is not a zip file")
#    1337         if self.debug > 1:
#    1338             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
df_Opt.columns =['Timestamp', 'Amount_USD']
df_Opt
# Out:
#                     Timestamp   Amount_USD
# 0         2022-02-04 12:45:58     0.000000
# 1         2022-02-06 01:41:30     0.000000
# 2         2022-02-02 09:34:18     0.000000
# 3         2022-02-02 09:34:18  1070.680722
# 4         2022-02-03 09:14:12     0.000000
# ...                       ...          ...
# 17428300  2022-06-02 22:23:01   151.039205
# 17428301  2022-06-02 07:33:25     0.999306
# 17428302  2022-06-02 07:33:25     0.999778
# 17428303  2022-06-02 23:10:39    19.596420
# 17428304  2022-06-02 08:33:53   589.177835
#
# [17428305 rows x 2 columns]

# %%
Opt_Amount=df_Opt

# %%
Opt_Amount=Opt_Amount.sort_values(by='Timestamp')
Opt_Amount
# Out:
#                     Timestamp   Amount_USD
# 13982     2022-02-01 00:03:14     0.000000
# 51878     2022-02-01 00:03:14     0.000000
# 38688     2022-02-01 00:03:14  1263.197957
# 12137     2022-02-01 00:03:14     0.000000
# 34189     2022-02-01 00:03:14     0.000000
# ...                       ...          ...
# 15272496  2022-12-31 23:59:56     0.000000
# 15270867  2022-12-31 23:59:56    41.736739
# 15278487  2022-12-31 23:59:56    62.923161
# 15312565  2022-12-31 23:59:56    29.935998
# 15289389  2022-12-31 23:59:56     0.054918
#
# [17428305 rows x 2 columns]

# %%
Opt_Amount.to_csv("Opt_Amount.csv")
