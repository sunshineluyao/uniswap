# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Poly'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Poly/May" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Poly/May'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_polygon_2022_05_01.xlsx', 'uniswap_polygon_2022_05_02.xlsx', 'uniswap_polygon_2022_05_03.xlsx', 'uniswap_polygon_2022_05_04.xlsx', 'uniswap_polygon_2022_05_05.xlsx', 'uniswap_polygon_2022_05_06.xlsx', 'uniswap_polygon_2022_05_07.xlsx', 'uniswap_polygon_2022_05_08.xlsx', 'uniswap_polygon_2022_05_09.xlsx', 'uniswap_polygon_2022_05_10_PM.xlsx', 'uniswap_polygon_2022_05_11_PM.xlsx', 'uniswap_polygon_2022_05_11_AM.xlsx', 'uniswap_polygon_2022_05_12_AM.xlsx', 'uniswap_polygon_2022_05_13_AM.xlsx', 'uniswap_polygon_2022_05_13_PM.xlsx', 'uniswap_polygon_2022_05_14_AM.xlsx', 'uniswap_polygon_2022_05_16.xlsx', 'uniswap_polygon_2022_05_14_PM.xlsx', 'uniswap_polygon_2022_05_15.xlsx', 'uniswap_polygon_2022_05_17.xlsx', 'uniswap_polygon_2022_05_18.xlsx', 'uniswap_polygon_2022_05_19.xlsx', 'uniswap_polygon_2022_05_20.xlsx', 'uniswap_polygon_2022_05_21.xlsx', 'uniswap_polygon_2022_05_22.xlsx', 'uniswap_polygon_2022_05_23.xlsx', 'uniswap_polygon_2022_05_24.xlsx', 'uniswap_polygon_2022_05_25.
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_polygon_2022_05_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x0000a0a158ae8b54838f47e2c17dc175c5cf5dd5d344...
# 1  0x000532693c9335a9253fc24190dca235ef7bdced5c4b...
# 2  0x000532693c9335a9253fc24190dca235ef7bdced5c4b...
# 3  0x00054959787a85d5e8093a69eb150060336af0df86bd...
# 4  0x00054959787a85d5e8093a69eb150060336af0df86bd...
#
#                                       Transaction ID           Timestamp  \
# 0  0x0000a0a158ae8b54838f47e2c17dc175c5cf5dd5d344... 2022-05-01 20:04:37
# 1  0x000532693c9335a9253fc24190dca235ef7bdced5c4b... 2022-05-01 12:35:45
# 2  0x000532693c9335a9253fc24190dca235ef7bdced5c4b... 2022-05-01 12:35:45
# 3  0x00054959787a85d5e8093a69eb150060336af0df86bd... 2022-05-01 09:26:25
# 4  0x00054959787a85d5e8093a69eb150060336af0df86bd... 2022-05-01 09:26:25
#
#    Timestamp (Unix)                                        Pool  \
# 0        1651460677  0x45dda9cb7c25131df268515131f647d726f50608
# 1        1651433745  0x86f1d8390222a3691c28938ec7404a1661e618e0
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 81517  0xfffb109711a26272d2fe942f32ce8c2f301d67c5bd9e...
# 81518  0xfffb5d3d69db5992f0ea838df208d7c2b8a4b6d6ae5d...
# 81519  0xfffd20cb4ebb2d3b2538c4c737a2336c0407bac7977d...
# 81520  0xfffd931a91bff0e1d63fd99003b7b291a60e2c55072f...
# 81521  0xfffd931a91bff0e1d63fd99003b7b291a60e2c55072f...
#
#                                           Transaction ID           Timestamp  \
# 81517  0xfffb109711a26272d2fe942f32ce8c2f301d67c5bd9e... 2022-05-01 18:11:59
# 81518  0xfffb5d3d69db5992f0ea838df208d7c2b8a4b6d6ae5d... 2022-05-01 17:03:55
# 81519  0xfffd20cb4ebb2d3b2538c4c737a2336c0407bac7977d... 2022-05-01 10:37:46
# 81520  0xfffd931a91bff0e1d63fd99003b7b291a60e2c55072f... 2022-05-01 12:00:32
# 81521  0xfffd931a91bff0e1d63fd99003b7b291a60e2c55072f... 2022-05-01 12:00:32
#
#        Timestamp (Unix)                                        Pool  \
# 81517        1651453919  0xa374094527e1673a86de625aa59517c5de346d32
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 36/36 [12:35<00:00, 20.99s/it]

# %%
df_Poly_May = df
df_Poly_May.tail()
# Out:
#                                                         ID  \
# 2946589  0xfffb80deff0bc9923b85bbaea45d5630710c695fae0a...
# 2946590  0xfffb80deff0bc9923b85bbaea45d5630710c695fae0a...
# 2946591  0xfffb80deff0bc9923b85bbaea45d5630710c695fae0a...
# 2946592  0xfffe7e66116dd146fe572857266be59e9f0d59adcd8c...
# 2946593  0xfffe7e66116dd146fe572857266be59e9f0d59adcd8c...
#
#                                             Transaction ID  \
# 2946589  0xfffb80deff0bc9923b85bbaea45d5630710c695fae0a...
# 2946590  0xfffb80deff0bc9923b85bbaea45d5630710c695fae0a...
# 2946591  0xfffb80deff0bc9923b85bbaea45d5630710c695fae0a...
# 2946592  0xfffe7e66116dd146fe572857266be59e9f0d59adcd8c...
# 2946593  0xfffe7e66116dd146fe572857266be59e9f0d59adcd8c...
#
#                   Timestamp  Timestamp (Unix)  \
# 2946589 2022-05-12 17:32:58        1652401978
# 2946590 2022-05-12 17:32:58        1652401978
# 2946591 2022-05-12 17:32:58        1652401978
# 2946592 2022-05-12 16:15:36        1652397336
# ...

# %%
df_Poly_May.to_csv("Poly_May.csv")

# %%
df_Poly_May = pd.read_csv("Poly_May.csv")

# %%
Poly_Amount_May = df_Poly_May[["Timestamp", "Amount USD (Excel)"]]

# %%
Poly_Amount_May.columns =['Timestamp', 'Amount_USD']
Poly_Amount_May
# Out:
#                    Timestamp   Amount_USD
# 0        2022-05-01 20:04:37  9948.511712
# 1        2022-05-01 12:35:45    58.159060
# 2        2022-05-01 12:35:45    58.194039
# 3        2022-05-01 09:26:25   574.014008
# 4        2022-05-01 09:26:25   309.106844
# ...                      ...          ...
# 2946589  2022-05-12 17:32:58    19.105164
# 2946590  2022-05-12 17:32:58    19.110348
# 2946591  2022-05-12 17:32:58    19.100252
# 2946592  2022-05-12 16:15:36    10.937191
# 2946593  2022-05-12 16:15:36    10.931847
#
# [2946594 rows x 2 columns]

# %%
Poly_Amount_May['Timestamp']=pd.to_datetime(Poly_Amount_May['Timestamp'])
Poly_Amount_May.dtypes
# Out:
# <ipython-input-16-03cb5df80e65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Poly_Amount_May['Timestamp']=pd.to_datetime(Poly_Amount_May['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Poly_Amount_May=Poly_Amount_May.sort_values(by='Timestamp')
Poly_Amount_May
# Out:
#                   Timestamp   Amount_USD
# 24001   2022-05-01 00:00:02   550.116695
# 114521  2022-05-01 00:00:02   106.999486
# 67030   2022-05-01 00:00:02  3266.063695
# 114522  2022-05-01 00:00:02   107.204490
# 33000   2022-05-01 00:00:02   107.204490
# ...                     ...          ...
# 2773888 2022-05-31 23:59:44    57.463564
# 2723244 2022-05-31 23:59:48    67.438770
# 2723243 2022-05-31 23:59:48    67.412329
# 2790040 2022-05-31 23:59:52    11.582498
# 2790039 2022-05-31 23:59:52    11.589938
#
# [2946594 rows x 2 columns]

# %%
Poly_Amount_May.to_csv("Poly_Amount_May.csv")
