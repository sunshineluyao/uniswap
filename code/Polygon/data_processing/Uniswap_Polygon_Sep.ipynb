# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Poly'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Poly/September" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Poly/September'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_polygon_2022_09_01.xlsx', 'uniswap_polygon_2022_09_02.xlsx', 'uniswap_polygon_2022_09_03.xlsx', 'uniswap_polygon_2022_09_04.xlsx', 'uniswap_polygon_2022_09_05.xlsx', 'uniswap_polygon_2022_09_06.xlsx', 'uniswap_polygon_2022_09_07.xlsx', 'uniswap_polygon_2022_09_09.xlsx', 'uniswap_polygon_2022_09_08.xlsx', 'uniswap_polygon_2022_09_10.xlsx', 'uniswap_polygon_2022_09_11.xlsx', 'uniswap_polygon_2022_09_12.xlsx', 'uniswap_polygon_2022_09_13.xlsx', 'uniswap_polygon_2022_09_15.xlsx', 'uniswap_polygon_2022_09_14.xlsx', 'uniswap_polygon_2022_09_17.xlsx', 'uniswap_polygon_2022_09_16.xlsx', 'uniswap_polygon_2022_09_18.xlsx', 'uniswap_polygon_2022_09_19.xlsx', 'uniswap_polygon_2022_09_20.xlsx', 'uniswap_polygon_2022_09_21.xlsx', 'uniswap_polygon_2022_09_22.xlsx', 'uniswap_polygon_2022_09_23.xlsx', 'uniswap_polygon_2022_09_25.xlsx', 'uniswap_polygon_2022_09_24.xlsx', 'uniswap_polygon_2022_09_26.xlsx', 'uniswap_polygon_2022_09_27.xlsx', 'uniswap_polygon_2022_09_28.xlsx', 'uniswap_polygon_
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_polygon_2022_09_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x000004ce0de2081221529d78773049ed10ef169171b5...
# 1  0x000078b24f5d9364e641ac473255e1869dfc789e89e8...
# 2  0x00016668c96a0df9808c6fc34e4097ff08e99a8d4871...
# 3  0x0002124ccc8c196916fdb0022271c69929032509f988...
# 4  0x0002a1c05105df51e973f89358f726657064fd50e9fd...
#
#                                       Transaction ID           Timestamp  \
# 0  0x000004ce0de2081221529d78773049ed10ef169171b5... 2022-09-01 03:18:51
# 1  0x000078b24f5d9364e641ac473255e1869dfc789e89e8... 2022-09-01 07:13:35
# 2  0x00016668c96a0df9808c6fc34e4097ff08e99a8d4871... 2022-09-01 19:40:31
# 3  0x0002124ccc8c196916fdb0022271c69929032509f988... 2022-09-01 16:00:28
# 4  0x0002a1c05105df51e973f89358f726657064fd50e9fd... 2022-09-01 05:48:54
#
#    Timestamp (Unix)                                        Pool  \
# 0        1662027531  0x45dda9cb7c25131df268515131f647d726f50608
# 1        1662041615  0x45dda9cb7c25131df268515131f647d726f50608
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 91903  0xfffd279e28ab24540d26f5c47799fe2d6d7d98abc9d8...
# 91904  0xfffde55130b4d0569c7bc2019c5544801b6fe7149ebe...
# 91905  0xfffe37eddb157116b1cd1e9b24ea10cf69e9c9bba91e...
# 91906  0xfffe37eddb157116b1cd1e9b24ea10cf69e9c9bba91e...
# 91907  0xffff69ac7878d4f75064f6b61604ccc81d0a200bca7d...
#
#                                           Transaction ID           Timestamp  \
# 91903  0xfffd279e28ab24540d26f5c47799fe2d6d7d98abc9d8... 2022-09-01 09:49:23
# 91904  0xfffde55130b4d0569c7bc2019c5544801b6fe7149ebe... 2022-09-01 20:09:19
# 91905  0xfffe37eddb157116b1cd1e9b24ea10cf69e9c9bba91e... 2022-09-01 07:52:41
# 91906  0xfffe37eddb157116b1cd1e9b24ea10cf69e9c9bba91e... 2022-09-01 07:52:41
# 91907  0xffff69ac7878d4f75064f6b61604ccc81d0a200bca7d... 2022-09-01 21:27:22
#
#        Timestamp (Unix)                                        Pool  \
# 91903        1662050963  0x45dda9cb7c25131df268515131f647d726f50608
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 30/30 [12:48<00:00, 25.62s/it]

# %%
df_Poly_Sep = df
df_Poly_Sep.tail()
# Out:
#                                                         ID  \
# 2964164  0xfff9a93aa635aa1cf219ee855d4e11b85bf6fe237f01...
# 2964165  0xfffa013ba60ddc97a8f36f8384eea67702aa0c7fdfe0...
# 2964166  0xfffab93db6086ff025d4d44cb4aab5d483d3244995c5...
# 2964167  0xffff03c8acf9a8e4d4e3f48d2da3ba97aefc2dd733a9...
# 2964168  0xffffacb04d2734e426b9bd517f92eac4f41a93b6ebcc...
#
#                                             Transaction ID  \
# 2964164  0xfff9a93aa635aa1cf219ee855d4e11b85bf6fe237f01...
# 2964165  0xfffa013ba60ddc97a8f36f8384eea67702aa0c7fdfe0...
# 2964166  0xfffab93db6086ff025d4d44cb4aab5d483d3244995c5...
# 2964167  0xffff03c8acf9a8e4d4e3f48d2da3ba97aefc2dd733a9...
# 2964168  0xffffacb04d2734e426b9bd517f92eac4f41a93b6ebcc...
#
#                   Timestamp  Timestamp (Unix)  \
# 2964164 2022-09-30 03:27:41        1664533661
# 2964165 2022-09-30 23:08:21        1664604501
# 2964166 2022-09-30 09:51:41        1664556701
# 2964167 2022-09-30 12:42:02        1664566922
# ...

# %%
df_Poly_Sep.to_csv("Poly_Sep.csv")

# %%
df_Poly_Sep = pd.read_csv("Poly_Sep.csv")

# %%
Poly_Amount_Sep = df_Poly_Sep[["Timestamp", "Amount USD (Excel)"]]

# %%
Poly_Amount_Sep.columns =['Timestamp', 'Amount_USD']
Poly_Amount_Sep
# Out:
#                    Timestamp    Amount_USD
# 0        2022-09-01 03:18:51   1995.914919
# 1        2022-09-01 07:13:35  10815.201971
# 2        2022-09-01 19:40:31    219.500540
# 3        2022-09-01 16:00:28   1109.373759
# 4        2022-09-01 05:48:54      7.801847
# ...                      ...           ...
# 2964164  2022-09-30 03:27:41     52.017153
# 2964165  2022-09-30 23:08:21     49.090758
# 2964166  2022-09-30 09:51:41     23.877971
# 2964167  2022-09-30 12:42:02     24.608570
# 2964168  2022-09-30 11:13:12     79.184968
#
# [2964169 rows x 2 columns]

# %%
Poly_Amount_Sep['Timestamp']=pd.to_datetime(Poly_Amount_Sep['Timestamp'])
Poly_Amount_Sep.dtypes
# Out:
# <ipython-input-19-7822fd5f1166>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Poly_Amount_Sep['Timestamp']=pd.to_datetime(Poly_Amount_Sep['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Poly_Amount_Sep=Poly_Amount_Sep.sort_values(by='Timestamp')
Poly_Amount_Sep
# Out:
#                   Timestamp  Amount_USD
# 105686  2022-09-01 00:00:05    9.754973
# 13778   2022-09-01 00:00:05    9.754973
# 35740   2022-09-01 00:00:07   31.264010
# 40865   2022-09-01 00:00:07   63.124374
# 183460  2022-09-01 00:00:07   29.019610
# ...                     ...         ...
# 2890384 2022-09-30 23:59:51   15.175565
# 2872801 2022-09-30 23:59:51   27.761576
# 2863259 2022-09-30 23:59:53    3.374734
# 2892130 2022-09-30 23:59:53  106.031958
# 2922761 2022-09-30 23:59:55  499.715813
#
# [2964169 rows x 2 columns]

# %%
Poly_Amount_Sep.to_csv("Poly_Amount_Sep.csv")
