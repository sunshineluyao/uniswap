# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Poly'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Poly/April" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Poly/April'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_polygon_2022_04_01.xlsx', 'uniswap_polygon_2022_04_02.xlsx', 'uniswap_polygon_2022_04_03.xlsx', 'uniswap_polygon_2022_04_04.xlsx', 'uniswap_polygon_2022_04_05.xlsx', 'uniswap_polygon_2022_04_06.xlsx', 'uniswap_polygon_2022_04_07.xlsx', 'uniswap_polygon_2022_04_08.xlsx', 'uniswap_polygon_2022_04_09.xlsx', 'uniswap_polygon_2022_04_10.xlsx', 'uniswap_polygon_2022_04_12.xlsx', 'uniswap_polygon_2022_04_14.xlsx', 'uniswap_polygon_2022_04_11.xlsx', 'uniswap_polygon_2022_04_13.xlsx', 'uniswap_polygon_2022_04_16.xlsx', 'uniswap_polygon_2022_04_18.xlsx', 'uniswap_polygon_2022_04_15.xlsx', 'uniswap_polygon_2022_04_17.xlsx', 'uniswap_polygon_2022_04_20.xlsx', 'uniswap_polygon_2022_04_22.xlsx', 'uniswap_polygon_2022_04_19.xlsx', 'uniswap_polygon_2022_04_21.xlsx', 'uniswap_polygon_2022_04_23.xlsx', 'uniswap_polygon_2022_04_24.xlsx', 'uniswap_polygon_2022_04_25.xlsx', 'uniswap_polygon_2022_04_28.xlsx', 'uniswap_polygon_2022_04_27.xlsx', 'uniswap_polygon_2022_04_30.xlsx', 'uniswap_polygon_
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_polygon_2022_04_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x000093e14e2a2d4600d13cbe12a2d21692c2f1d6075b...
# 1  0x000140f84bf47ed69e403c1b62f183babb97056cfb0d...
# 2  0x000242d638bf7b87bf230e51e55f321a3d622a533c16...
# 3  0x00025f37403a1d699075a468b8524395cbf34542814f...
# 4  0x000439cc91d5015e414703430028bedfca72c1f8e0bd...
#
#                                       Transaction ID           Timestamp  \
# 0  0x000093e14e2a2d4600d13cbe12a2d21692c2f1d6075b... 2022-04-01 03:30:36
# 1  0x000140f84bf47ed69e403c1b62f183babb97056cfb0d... 2022-04-01 18:18:08
# 2  0x000242d638bf7b87bf230e51e55f321a3d622a533c16... 2022-04-01 15:44:48
# 3  0x00025f37403a1d699075a468b8524395cbf34542814f... 2022-04-01 06:37:34
# 4  0x000439cc91d5015e414703430028bedfca72c1f8e0bd... 2022-04-01 17:30:34
#
#    Timestamp (Unix)                                        Pool  \
# 0        1648809036  0x1b40b17d04af7ecf70b553fb3b5e793b8972b414
# 1        1648862288  0x45dda9cb7c25131df268515131f647d726f50608
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1.tail()
# Out:
#                                                       ID  \
# 64439  0xfffb513ae0e32c17a443fc5c73b1b061b496ffeec391...
# 64440  0xfffbc307422dfb7bce991b97067bc88fe49be93451ed...
# 64441  0xfffbc307422dfb7bce991b97067bc88fe49be93451ed...
# 64442  0xfffc3a21f2315fcb98bdf37747b7a6eb5399c4320a45...
# 64443  0xfffc3a21f2315fcb98bdf37747b7a6eb5399c4320a45...
#
#                                           Transaction ID           Timestamp  \
# 64439  0xfffb513ae0e32c17a443fc5c73b1b061b496ffeec391... 2022-04-01 05:18:50
# 64440  0xfffbc307422dfb7bce991b97067bc88fe49be93451ed... 2022-04-01 05:32:38
# 64441  0xfffbc307422dfb7bce991b97067bc88fe49be93451ed... 2022-04-01 05:32:38
# 64442  0xfffc3a21f2315fcb98bdf37747b7a6eb5399c4320a45... 2022-04-01 07:55:01
# 64443  0xfffc3a21f2315fcb98bdf37747b7a6eb5399c4320a45... 2022-04-01 07:55:01
#
#        Timestamp (Unix)                                        Pool  \
# 64439        1648815530  0xa374094527e1673a86de625aa59517c5de346d32
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 30/30 [07:40<00:00, 15.35s/it]

# %%
df_Poly_Apr = df
df_Poly_Apr.tail()
# Out:
#                                                         ID  \
# 1836765  0xfffa043cdd1570ea6a0afeb9376f19691dc19e1db4d0...
# 1836766  0xfffbf536d49a7c585c8fe95b5a8e7e87d127383e4051...
# 1836767  0xfffbf536d49a7c585c8fe95b5a8e7e87d127383e4051...
# 1836768  0xffff2609c511a182d2ea465e868427e050cbf4204b98...
# 1836769  0xffff2609c511a182d2ea465e868427e050cbf4204b98...
#
#                                             Transaction ID  \
# 1836765  0xfffa043cdd1570ea6a0afeb9376f19691dc19e1db4d0...
# 1836766  0xfffbf536d49a7c585c8fe95b5a8e7e87d127383e4051...
# 1836767  0xfffbf536d49a7c585c8fe95b5a8e7e87d127383e4051...
# 1836768  0xffff2609c511a182d2ea465e868427e050cbf4204b98...
# 1836769  0xffff2609c511a182d2ea465e868427e050cbf4204b98...
#
#                   Timestamp  Timestamp (Unix)  \
# 1836765 2022-04-26 19:33:00        1651026780
# 1836766 2022-04-26 00:06:53        1650956813
# 1836767 2022-04-26 00:06:53        1650956813
# 1836768 2022-04-26 09:24:03        1650990243
# ...

# %%
df_Poly_Apr.to_csv("Poly_Apr.csv")

# %%
df_Poly_Apr = pd.read_csv("Poly_Apr.csv")

# %%
Poly_Amount_Apr = df_Poly_Apr[["Timestamp", "Amount USD (Excel)"]]

# %%
Poly_Amount_Apr.columns =['Timestamp', 'Amount_USD']
Poly_Amount_Apr
# Out:
#                    Timestamp   Amount_USD
# 0        2022-04-01 03:30:36     5.164560
# 1        2022-04-01 18:18:08  6767.580138
# 2        2022-04-01 15:44:48   305.773271
# 3        2022-04-01 06:37:34   498.070160
# 4        2022-04-01 17:30:34    25.287576
# ...                      ...          ...
# 1836765  2022-04-26 19:33:00   494.636343
# 1836766  2022-04-26 00:06:53  5333.374165
# 1836767  2022-04-26 00:06:53  5316.360246
# 1836768  2022-04-26 09:24:03  1435.815647
# 1836769  2022-04-26 09:24:03  1438.984040
#
# [1836770 rows x 2 columns]

# %%
Poly_Amount_Apr['Timestamp']=pd.to_datetime(Poly_Amount_Apr['Timestamp'])
Poly_Amount_Apr.dtypes
# Out:
# <ipython-input-17-0d5db9ee5328>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Poly_Amount_Apr['Timestamp']=pd.to_datetime(Poly_Amount_Apr['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Poly_Amount_Apr=Poly_Amount_Apr.sort_values(by='Timestamp')
Poly_Amount_Apr
# Out:
#                   Timestamp  Amount_USD
# 63018   2022-04-01 00:00:00    1.618098
# 127462  2022-04-01 00:00:00    1.618098
# 127461  2022-04-01 00:00:00    1.618503
# 63017   2022-04-01 00:00:00    1.618503
# 127767  2022-04-01 00:00:02   33.540433
# ...                     ...         ...
# 1681484 2022-04-30 23:59:58  285.162657
# 1630728 2022-04-30 23:59:58   26.114930
# 1630729 2022-04-30 23:59:58  435.421424
# 1630730 2022-04-30 23:59:58  148.009454
# 1630344 2022-04-30 23:59:58  133.730175
#
# [1836770 rows x 2 columns]

# %%
Poly_Amount_Apr.to_csv("Poly_Amount_Apr.csv")
