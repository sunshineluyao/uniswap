# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Poly

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Poly'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Poly/March" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Poly/March'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_polygon_2022_03_01.xlsx', 'uniswap_polygon_2022_03_02.xlsx', 'uniswap_polygon_2022_03_03.xlsx', 'uniswap_polygon_2022_03_04.xlsx', 'uniswap_polygon_2022_03_05.xlsx', 'uniswap_polygon_2022_03_06.xlsx', 'uniswap_polygon_2022_03_07.xlsx', 'uniswap_polygon_2022_03_08.xlsx', 'uniswap_polygon_2022_03_09.xlsx', 'uniswap_polygon_2022_03_10.xlsx', 'uniswap_polygon_2022_03_11.xlsx', 'uniswap_polygon_2022_03_12.xlsx', 'uniswap_polygon_2022_03_13.xlsx', 'uniswap_polygon_2022_03_14.xlsx', 'uniswap_polygon_2022_03_15.xlsx', 'uniswap_polygon_2022_03_17.xlsx', 'uniswap_polygon_2022_03_16.xlsx', 'uniswap_polygon_2022_03_18.xlsx', 'uniswap_polygon_2022_03_19.xlsx', 'uniswap_polygon_2022_03_20.xlsx', 'uniswap_polygon_2022_03_21.xlsx', 'uniswap_polygon_2022_03_22.xlsx', 'uniswap_polygon_2022_03_23.xlsx', 'uniswap_polygon_2022_03_24.xlsx', 'uniswap_polygon_2022_03_25.xlsx', 'uniswap_polygon_2022_03_27.xlsx', 'uniswap_polygon_2022_03_26.xlsx', 'uniswap_polygon_2022_03_28.xlsx', 'uniswap_polygon_
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_polygon_2022_03_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x000077be55b39ecb6d48b2facbbcfac1c21b95239d02...
# 1  0x00027955b5f76e631c6d698f1ac8112596af3c986990...
# 2  0x0002b7f631e1c750c358c8099db2d2f115707185996e...
# 3  0x000302077cf3cbdda1b0949ae01b25d1ddb1873580c5...
# 4  0x000302077cf3cbdda1b0949ae01b25d1ddb1873580c5...
#
#                                       Transaction ID           Timestamp  \
# 0  0x000077be55b39ecb6d48b2facbbcfac1c21b95239d02... 2022-03-01 01:26:24
# 1  0x00027955b5f76e631c6d698f1ac8112596af3c986990... 2022-03-01 19:47:34
# 2  0x0002b7f631e1c750c358c8099db2d2f115707185996e... 2022-03-01 17:55:05
# 3  0x000302077cf3cbdda1b0949ae01b25d1ddb1873580c5... 2022-03-01 18:57:10
# 4  0x000302077cf3cbdda1b0949ae01b25d1ddb1873580c5... 2022-03-01 18:57:10
#
#    Timestamp (Unix)                                        Pool  \
# 0        1646126784  0x45dda9cb7c25131df268515131f647d726f50608
# 1        1646192854  0xfe343675878100b344802a6763fd373fdeed07a4
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 70743  0xfffa0f327de054d3abd841fb0430a3db9618d1197855...
# 70744  0xfffadd4be0f5a02a4171afea6e02131d1d2dc2b86680...
# 70745  0xfffc3b4ce378190d44783a45e258ca911f9f386d493f...
# 70746  0xfffc3b4ce378190d44783a45e258ca911f9f386d493f...
# 70747  0xfffea6d748f68692b235afae8d109dca1d183fcf7495...
#
#                                           Transaction ID           Timestamp  \
# 70743  0xfffa0f327de054d3abd841fb0430a3db9618d1197855... 2022-03-01 11:42:31
# 70744  0xfffadd4be0f5a02a4171afea6e02131d1d2dc2b86680... 2022-03-01 17:15:32
# 70745  0xfffc3b4ce378190d44783a45e258ca911f9f386d493f... 2022-03-01 08:46:34
# 70746  0xfffc3b4ce378190d44783a45e258ca911f9f386d493f... 2022-03-01 08:46:34
# 70747  0xfffea6d748f68692b235afae8d109dca1d183fcf7495... 2022-03-01 22:46:24
#
#        Timestamp (Unix)                                        Pool  \
# 70743        1646163751  0xa374094527e1673a86de625aa59517c5de346d32
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 31/31 [06:59<00:00, 13.53s/it]

# %%
df_Poly_Mar = df
df_Poly_Mar.tail()
# Out:
#                                                         ID  \
# 1592713  0xfffc67191f1e5c5c33d467a4d868b05ac32ec490e20c...
# 1592714  0xfffd3fc970cba8d67b5996aa8ced84132cf0b1c7faf3...
# 1592715  0xfffd4f51e9a2538117ed97261653801955322e32175b...
# 1592716  0xfffd4f51e9a2538117ed97261653801955322e32175b...
# 1592717  0xffffb35c8160c0598a15f610986ebc69b796775f6d89...
#
#                                             Transaction ID  \
# 1592713  0xfffc67191f1e5c5c33d467a4d868b05ac32ec490e20c...
# 1592714  0xfffd3fc970cba8d67b5996aa8ced84132cf0b1c7faf3...
# 1592715  0xfffd4f51e9a2538117ed97261653801955322e32175b...
# 1592716  0xfffd4f51e9a2538117ed97261653801955322e32175b...
# 1592717  0xffffb35c8160c0598a15f610986ebc69b796775f6d89...
#
#                   Timestamp  Timestamp (Unix)  \
# 1592713 2022-03-31 17:12:20        1648771940
# 1592714 2022-03-31 06:17:33        1648732653
# 1592715 2022-03-31 05:51:09        1648731069
# 1592716 2022-03-31 05:51:09        1648731069
# ...

# %%
df_Poly_Mar.to_csv("Poly_Mar.csv")

# %%
df_Poly_Mar = pd.read_csv("Poly_Mar.csv")

# %%
Poly_Amount_Mar = df_Poly_Mar[["Timestamp", "Amount USD (Excel)"]]

# %%
Poly_Amount_Mar.columns =['Timestamp', 'Amount_USD']
Poly_Amount_Mar

# %%
Poly_Amount_Mar['Timestamp']=pd.to_datetime(Poly_Amount_Mar['Timestamp'])
Poly_Amount_Mar.dtypes

# %%
Poly_Amount_Mar=Poly_Amount_Mar.sort_values(by='Timestamp')
Poly_Amount_Mar

# %%
Poly_Amount_Mar.to_csv("Poly_Amount_Mar.csv")
