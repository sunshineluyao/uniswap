# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2021/June" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2021/June'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2021_06_2and3.xlsx', 'uniswap_ethereum_2021_06_1.xlsx', 'uniswap_ethereum_2021_06_4.xlsx', 'uniswap_ethereum_2021_06_5.xlsx', 'uniswap_ethereum_2021_06_6.xlsx', 'uniswap_ethereum_2021_06_7.xlsx', 'uniswap_ethereum_2021_06_8.xlsx', 'uniswap_ethereum_2021_06_9.xlsx', 'uniswap_ethereum_2021_06_10.xlsx', 'uniswap_ethereum_2021_06_11.xlsx', 'uniswap_ethereum_2021_06_12.xlsx', 'uniswap_ethereum_2021_06_13.xlsx', 'uniswap_ethereum_2021_06_14.xlsx', 'uniswap_ethereum_2021_06_15.xlsx', 'uniswap_ethereum_2021_06_16.xlsx', 'uniswap_ethereum_2021_06_17.xlsx', 'uniswap_ethereum_2021_06_18.xlsx', 'uniswap_ethereum_2021_06_19.xlsx', 'uniswap_ethereum_2021_06_20.xlsx', 'uniswap_ethereum_2021_06_21.xlsx', 'uniswap_ethereum_2021_06_22.xlsx', 'uniswap_ethereum_2021_06_23.xlsx', 'uniswap_ethereum_2021_06_24.xlsx', 'uniswap_ethereum_2021_06_25.xlsx', 'uniswap_ethereum_2021_06_26.xlsx', 'uniswap_ethereum_2021_06_27.xlsx', 'uniswap_ethereum_2021_06_28.xlsx', 'uniswap_ethereum_2021_06_29.
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2021_06_1.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x0001fd59e6a29104f06c8a08060ed702ce10dff10faa...
# 1  0x00045bced0ba6624242b8e3a5361ec345231617039ec...
# 2  0x0005b18aa57f8fa92da0fbc13567235181403e0ebb73...
# 3  0x000bf878128e7b7343f47aa4de014de9fe7de7af72ee...
# 4  0x000d85125516e75ece41c0d892bb99021a59adef481f...
#
#                                       Transaction ID           Timestamp  \
# 0  0x0001fd59e6a29104f06c8a08060ed702ce10dff10faa... 2021-06-01 06:41:15
# 1  0x00045bced0ba6624242b8e3a5361ec345231617039ec... 2021-06-01 04:17:30
# 2  0x0005b18aa57f8fa92da0fbc13567235181403e0ebb73... 2021-06-01 12:51:40
# 3  0x000bf878128e7b7343f47aa4de014de9fe7de7af72ee... 2021-06-01 07:44:34
# 4  0x000d85125516e75ece41c0d892bb99021a59adef481f... 2021-06-01 14:32:28
#
#    Timestamp (Unix)                                        Pool  \
# 0        1622554875  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8
# 1        1622546250  0xcb0c5d9d92f4f2f80cce7aa271a1e148c226e19d
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 24965  0xfff47e40aa81481eb16ff70ec167146b345d928ec3ef...
# 24966  0xfff67c08e0b45d02da274fa5b07770b5656bd10c056b...
# 24967  0xfff7c27b01154a3bc308174d0a8df420f74b0930f2aa...
# 24968  0xfff82906d06f272e716895af7a267c435cc50fd96357...
# 24969  0xfff82906d06f272e716895af7a267c435cc50fd96357...
#
#                                           Transaction ID           Timestamp  \
# 24965  0xfff47e40aa81481eb16ff70ec167146b345d928ec3ef... 2021-06-01 17:48:03
# 24966  0xfff67c08e0b45d02da274fa5b07770b5656bd10c056b... 2021-06-01 08:48:44
# 24967  0xfff7c27b01154a3bc308174d0a8df420f74b0930f2aa... 2021-06-01 05:51:56
# 24968  0xfff82906d06f272e716895af7a267c435cc50fd96357... 2021-06-01 12:30:33
# 24969  0xfff82906d06f272e716895af7a267c435cc50fd96357... 2021-06-01 12:30:33
#
#        Timestamp (Unix)                                        Pool  \
# 24965        1622594883  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#   7%|▋         | 2/29 [00:23<04:54, 10.91s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  10%|█         | 3/29 [00:32<04:15,  9.82s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  14%|█▍        | 4/29 [00:41<03:54,  9.39s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  17%|█▋        | 5/29 [00:49<03:39,  9.15s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ...

# %%
df_Eth_June2021 = df
df_Eth_June2021.tail()
# Out:
#                                                         ID  \
# 1246787  0xfffc95a8d7c1de0a69e436b4bd6f3d756f7fcb21d890...
# 1246788  0xfffd1d4d5efe6423b91b6513eabed963aa45d9324478...
# 1246789  0xfffe1eccb672608988d1fbd573a04cb5374780116c7b...
# 1246790  0xfffe94546ac217a4cf5728744619066bdea5db04e121...
# 1246791  0xffffc285647e62ed5e29f17da21dd0dc8b90cf6b3bbe...
#
#                                             Transaction ID  \
# 1246787  0xfffc95a8d7c1de0a69e436b4bd6f3d756f7fcb21d890...
# 1246788  0xfffd1d4d5efe6423b91b6513eabed963aa45d9324478...
# 1246789  0xfffe1eccb672608988d1fbd573a04cb5374780116c7b...
# 1246790  0xfffe94546ac217a4cf5728744619066bdea5db04e121...
# 1246791  0xffffc285647e62ed5e29f17da21dd0dc8b90cf6b3bbe...
#
#                   Timestamp  Timestamp (Unix)  \
# 1246787 2021-06-30 03:27:10        1625048830
# 1246788 2021-06-30 07:01:04        1625061664
# 1246789 2021-06-30 19:17:20        1625105840
# 1246790 2021-06-30 03:52:53        1625050373
# ...

# %%
df_Eth_June2021.to_csv("Eth_June2021.csv")

# %%
df_Eth_June2021 = pd.read_csv("Eth_June2021.csv")

# %%
Eth_Amount_June2021 = df_Eth_June2021[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_June2021.columns =['Timestamp', 'Amount_USD']
Eth_Amount_June2021
# Out:
#                    Timestamp     Amount_USD
# 0        2021-06-01 06:41:15  199586.804087
# 1        2021-06-01 04:17:30  189983.930865
# 2        2021-06-01 12:51:40    6010.497747
# 3        2021-06-01 07:44:34     523.341893
# 4        2021-06-01 14:32:28    1298.837481
# ...                      ...            ...
# 1246787  2021-06-30 03:27:10     218.654125
# 1246788  2021-06-30 07:01:04   25379.346207
# 1246789  2021-06-30 19:17:20    7004.790828
# 1246790  2021-06-30 03:52:53     483.995719
# 1246791  2021-06-30 18:59:08     303.789809
#
# [1246792 rows x 2 columns]

# %%
Eth_Amount_June2021['Timestamp']=pd.to_datetime(Eth_Amount_June2021['Timestamp'])
Eth_Amount_June2021.dtypes
# Out:
# <ipython-input-16-b3ff118f496b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_June2021['Timestamp']=pd.to_datetime(Eth_Amount_June2021['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_June2021=Eth_Amount_June2021.sort_values(by='Timestamp')
Eth_Amount_June2021
# Out:
#                   Timestamp    Amount_USD
# 98553   2021-06-01 00:00:20   6514.371593
# 115276  2021-06-01 00:00:20    122.752035
# 113358  2021-06-01 00:00:20   2499.814636
# 5034    2021-06-01 00:00:20  19977.308293
# 23443   2021-06-01 00:00:20    123.049852
# ...                     ...           ...
# 1213550 2021-06-30 23:59:55   9742.143628
# 1216132 2021-06-30 23:59:55   4319.985534
# 1216133 2021-06-30 23:59:55   4328.723290
# 1241067 2021-06-30 23:59:55   4574.051025
# 1232337 2021-06-30 23:59:55   6003.725399
#
# [1246792 rows x 2 columns]

# %%
Eth_Amount_June2021.to_csv("Eth_Amount_June2021.csv")
