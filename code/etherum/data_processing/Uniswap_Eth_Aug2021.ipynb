# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2021/August" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2021/August'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2021_08_1.xlsx', 'uniswap_ethereum_2021_08_2.xlsx', 'uniswap_ethereum_2021_08_3.xlsx', 'uniswap_ethereum_2021_08_4.xlsx', 'uniswap_ethereum_2021_08_5.xlsx', 'uniswap_ethereum_2021_08_6.xlsx', 'uniswap_ethereum_2021_08_7.xlsx', 'uniswap_ethereum_2021_08_8.xlsx', 'uniswap_ethereum_2021_08_9.xlsx', 'uniswap_ethereum_2021_08_10.xlsx', 'uniswap_ethereum_2021_08_11.xlsx', 'uniswap_ethereum_2021_08_12.xlsx', 'uniswap_ethereum_2021_08_13.xlsx', 'uniswap_ethereum_2021_08_14.xlsx', 'uniswap_ethereum_2021_08_15.xlsx', 'uniswap_ethereum_2021_08_16.xlsx', 'uniswap_ethereum_2021_08_17.xlsx', 'uniswap_ethereum_2021_08_18.xlsx', 'uniswap_ethereum_2021_08_19.xlsx', 'uniswap_ethereum_2021_08_20.xlsx', 'uniswap_ethereum_2021_08_21.xlsx', 'uniswap_ethereum_2021_08_22.xlsx', 'uniswap_ethereum_2021_08_23.xlsx', 'uniswap_ethereum_2021_08_24.xlsx', 'uniswap_ethereum_2021_08_25.xlsx', 'uniswap_ethereum_2021_08_26.xlsx', 'uniswap_ethereum_2021_08_27.xlsx', 'uniswap_ethereum_2021_08_28.xlsx'
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2021_08_1.xlsx")
df1.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                                   ID  \
# 0  0x0001432e0b006005502adb441f3a1591b89cc59217da...
# 1  0x0001432e0b006005502adb441f3a1591b89cc59217da...
# 2  0x00015408341f8846f316655bd7dbbe0a13a528b1388e...
# 3  0x0002871a442fb22ef0d4a661c9f1e504fa036a7a3eea...
# 4  0x00029af50edf1f9146cebfd60edd8072fefe4031f1f9...
#
#                                       Transaction ID           Timestamp  \
# 0  0x0001432e0b006005502adb441f3a1591b89cc59217da... 2021-08-01 18:25:09
# 1  0x0001432e0b006005502adb441f3a1591b89cc59217da... 2021-08-01 18:25:09
# 2  0x00015408341f8846f316655bd7dbbe0a13a528b1388e... 2021-08-01 18:12:09
# 3  0x0002871a442fb22ef0d4a661c9f1e504fa036a7a3eea... 2021-08-01 08:12:58
# 4  0x00029af50edf1f9146cebfd60edd8072fefe4031f1f9... 2021-08-01 06:12:05
#
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 46586  0xfffaf6a1b6a259c6b1d14d69f7bc26752c490ceffc55...
# 46587  0xfffbab289174c7a5716f376fe9248b045c06bdc3707b...
# 46588  0xfffbaf98be03414e838e56293b8930d9af4e9b08952c...
# 46589  0xfffbaf98be03414e838e56293b8930d9af4e9b08952c...
# 46590  0xffffd3d1acc719651c8639fb6b9a3e2938b314f3cb28...
#
#                                           Transaction ID           Timestamp  \
# 46586  0xfffaf6a1b6a259c6b1d14d69f7bc26752c490ceffc55... 2021-08-01 09:06:31
# 46587  0xfffbab289174c7a5716f376fe9248b045c06bdc3707b... 2021-08-01 20:07:32
# 46588  0xfffbaf98be03414e838e56293b8930d9af4e9b08952c... 2021-08-01 14:17:19
# 46589  0xfffbaf98be03414e838e56293b8930d9af4e9b08952c... 2021-08-01 14:17:19
# 46590  0xffffd3d1acc719651c8639fb6b9a3e2938b314f3cb28... 2021-08-01 05:49:13
#
#        Timestamp (Unix)                                        Pool  \
# 46586        1627833991  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 100%|██████████| 31/31 [06:10<00:00, 11.96s/it]

# %%
df_Eth_Aug2021 = df
df_Eth_Aug2021.tail()
# Out:
#                                                         ID  \
# 1272904  0xffecc85993573a456477ba5f27686e74092e44c310e2...
# 1272905  0xffecc85993573a456477ba5f27686e74092e44c310e2...
# 1272906  0xfff432c4ef983acfcb8e0d38f84bf8471440b82e2cf4...
# 1272907  0xfff82601a041a2ad54f913dd191b52bb408376ec1b20...
# 1272908  0xfffb67f970acc1a0eab71ec62bfc167858b8e29852d3...
#
#                                             Transaction ID  \
# 1272904  0xffecc85993573a456477ba5f27686e74092e44c310e2...
# 1272905  0xffecc85993573a456477ba5f27686e74092e44c310e2...
# 1272906  0xfff432c4ef983acfcb8e0d38f84bf8471440b82e2cf4...
# 1272907  0xfff82601a041a2ad54f913dd191b52bb408376ec1b20...
# 1272908  0xfffb67f970acc1a0eab71ec62bfc167858b8e29852d3...
#
#                   Timestamp  Timestamp (Unix)  \
# 1272904 2021-08-31 13:19:54        1630441194
# 1272905 2021-08-31 13:19:54        1630441194
# 1272906 2021-08-31 15:15:14        1630448114
# 1272907 2021-08-31 01:51:32        1630399892
# ...

# %%
df_Eth_Aug2021.to_csv("Eth_Aug2021.csv")

# %%
df_Eth_Aug2021 = pd.read_csv("Eth_Aug2021.csv")

# %%
Eth_Amount_Aug2021 = df_Eth_Aug2021[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Aug2021.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Aug2021
# Out:
#                    Timestamp    Amount_USD
# 0        2021-08-01 18:25:09    959.818520
# 1        2021-08-01 18:25:09    959.153758
# 2        2021-08-01 18:12:09    339.065775
# 3        2021-08-01 08:12:58   2802.854295
# 4        2021-08-01 06:12:05    214.083794
# ...                      ...           ...
# 1272904  2021-08-31 13:19:54   5481.751135
# 1272905  2021-08-31 13:19:54   5490.875568
# 1272906  2021-08-31 15:15:14  34118.672618
# 1272907  2021-08-31 01:51:32  33024.043201
# 1272908  2021-08-31 08:34:29    609.487979
#
# [1272909 rows x 2 columns]

# %%
Eth_Amount_Aug2021['Timestamp']=pd.to_datetime(Eth_Amount_Aug2021['Timestamp'])
Eth_Amount_Aug2021.dtypes
# Out:
# <ipython-input-26-baa2c6a80928>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Aug2021['Timestamp']=pd.to_datetime(Eth_Amount_Aug2021['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Aug2021=Eth_Amount_Aug2021.sort_values(by='Timestamp')
Eth_Amount_Aug2021
# Out:
#                   Timestamp     Amount_USD
# 85111   2021-08-01 00:00:29    6457.029735
# 2021    2021-08-01 00:00:29    1314.815806
# 86610   2021-08-01 00:00:29     282.388250
# 78376   2021-08-01 00:00:29     283.889561
# 31785   2021-08-01 00:00:29     283.889561
# ...                     ...            ...
# 1261348 2021-08-31 23:59:27  168100.831523
# 1261349 2021-08-31 23:59:27  168381.409477
# 1240276 2021-08-31 23:59:27  180467.654117
# 1251104 2021-08-31 23:59:27      93.956578
# 1271751 2021-08-31 23:59:27    1408.895043
#
# [1272909 rows x 2 columns]

# %%
Eth_Amount_Aug2021.to_csv("Eth_Amount_Aug2021.csv")
