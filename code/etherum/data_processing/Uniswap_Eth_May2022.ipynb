# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2022/May" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2022/May'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2022_05_01.xlsx', 'uniswap_ethereum_2022_05_02.xlsx', 'uniswap_ethereum_2022_05_03.xlsx', 'uniswap_ethereum_2022_05_04.xlsx', 'uniswap_ethereum_2022_05_05.xlsx', 'uniswap_ethereum_2022_05_06.xlsx', 'uniswap_ethereum_2022_05_07.xlsx', 'uniswap_ethereum_2022_05_08.xlsx', 'uniswap_ethereum_2022_05_09.xlsx', 'uniswap_ethereum_2022_05_10.xlsx', 'uniswap_ethereum_2022_05_11.xlsx', 'uniswap_ethereum_2022_05_12.xlsx', 'uniswap_ethereum_2022_05_13.xlsx', 'uniswap_ethereum_2022_05_14.xlsx', 'uniswap_ethereum_2022_05_15.xlsx', 'uniswap_ethereum_2022_05_16.xlsx', 'uniswap_ethereum_2022_05_17.xlsx', 'uniswap_ethereum_2022_05_18.xlsx', 'uniswap_ethereum_2022_05_19.xlsx', 'uniswap_ethereum_2022_05_20.xlsx', 'uniswap_ethereum_2022_05_21.xlsx', 'uniswap_ethereum_2022_05_22.xlsx', 'uniswap_ethereum_2022_05_23.xlsx', 'uniswap_ethereum_2022_05_24.xlsx', 'uniswap_ethereum_2022_05_25.xlsx', 'uniswap_ethereum_2022_05_26.xlsx', 'uniswap_ethereum_2022_05_27.xlsx', 'uniswap_ethereum_2022_05
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2022_05_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x00008c10c79798fce49986330474b8dddc284da106d6...
# 1  0x00008db1739018f185deba6144052cd7bbbc6be4250c...
# 2  0x0007e203725dd745d7b8f187bb7579022d7a90121e72...
# 3  0x000880e3e7934f0552bf54190cdb0be02cec4975e83e...
# 4  0x00097038c564afce799a44aff67041f8f98d194047c4...
#
#                                       Transaction ID           Timestamp  \
# 0  0x00008c10c79798fce49986330474b8dddc284da106d6... 2022-05-01 02:46:05
# 1  0x00008db1739018f185deba6144052cd7bbbc6be4250c... 2022-05-01 10:50:05
# 2  0x0007e203725dd745d7b8f187bb7579022d7a90121e72... 2022-05-01 15:54:19
# 3  0x000880e3e7934f0552bf54190cdb0be02cec4975e83e... 2022-05-01 02:26:48
# 4  0x00097038c564afce799a44aff67041f8f98d194047c4... 2022-05-01 05:15:38
#
#    Timestamp (Unix)                                        Pool  \
# 0        1651398365  0x82c427adfdf2d245ec51d8046b41c4ee87f0d29c
# 1        1651427405  0x4c54ff7f1c424ff5487a32aad0b48b19cbaf087f
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 33207  0xfffb155e54b4c96bf098d697deae4f30b79a7365e47f...
# 33208  0xfffb155e54b4c96bf098d697deae4f30b79a7365e47f...
# 33209  0xfffd02b51b1840e792d58b94926069162895ffdb0b81...
# 33210  0xfffd02b51b1840e792d58b94926069162895ffdb0b81...
# 33211  0xfffee21b3a89ee130a6d309ccf2bdaaac26c67dd93a2...
#
#                                           Transaction ID           Timestamp  \
# 33207  0xfffb155e54b4c96bf098d697deae4f30b79a7365e47f... 2022-05-01 01:07:03
# 33208  0xfffb155e54b4c96bf098d697deae4f30b79a7365e47f... 2022-05-01 01:07:03
# 33209  0xfffd02b51b1840e792d58b94926069162895ffdb0b81... 2022-05-01 02:25:36
# 33210  0xfffd02b51b1840e792d58b94926069162895ffdb0b81... 2022-05-01 02:25:36
# 33211  0xfffee21b3a89ee130a6d309ccf2bdaaac26c67dd93a2... 2022-05-01 04:51:29
#
#        Timestamp (Unix)                                        Pool  \
# 33207        1651392423  0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#  55%|█████▍    | 17/31 [03:19<02:50, 12.20s/it]

# %%
df_Eth_May = df
df_Eth_May.tail()

# %%
df_Eth_May.to_csv("Eth_May.csv")

# %%
df_Eth_May = pd.read_csv("Eth_May.csv")

# %%
Eth_Amount_May = df_Eth_May[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_May.columns =['Timestamp', 'Amount_USD']
Eth_Amount_May
# Out:
#                    Timestamp    Amount_USD
# 0        2022-05-01 02:46:05    137.358216
# 1        2022-05-01 10:50:05   6025.104537
# 2        2022-05-01 15:54:19  25028.618804
# 3        2022-05-01 02:26:48   5376.546727
# 4        2022-05-01 05:15:38  40014.134489
# ...                      ...           ...
# 1194931  2022-05-31 06:51:20    387.935033
# 1194932  2022-05-31 14:37:24  85198.917920
# 1194933  2022-05-31 13:14:48   4982.708632
# 1194934  2022-05-31 05:24:03  34236.579949
# 1194935  2022-05-31 05:16:47     48.962767
#
# [1194936 rows x 2 columns]

# %%
Eth_Amount_May['Timestamp']=pd.to_datetime(Eth_Amount_May['Timestamp'])
Eth_Amount_May.dtypes
# Out:
# <ipython-input-15-2d25aec60bdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_May['Timestamp']=pd.to_datetime(Eth_Amount_May['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_May=Eth_Amount_May.sort_values(by='Timestamp')
Eth_Amount_May
# Out:
#                   Timestamp     Amount_USD
# 10328   2022-05-01 00:00:06    2940.298316
# 54298   2022-05-01 00:00:06    6533.476402
# 65252   2022-05-01 00:00:06   11318.893423
# 25432   2022-05-01 00:00:06   10962.139524
# 39723   2022-05-01 00:00:06  104090.787691
# ...                     ...            ...
# 1186916 2022-05-31 23:59:57     103.843989
# 1176974 2022-05-31 23:59:57    8173.118571
# 1186667 2022-05-31 23:59:57    1327.129278
# 1193537 2022-05-31 23:59:57    1024.005822
# 1176973 2022-05-31 23:59:57    8121.242521
#
# [1194936 rows x 2 columns]

# %%
Eth_Amount_May.to_csv("Eth_Amount_May.csv")
