# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2022/Nov " #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2022/Nov '

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2022_11_01.xlsx', 'uniswap_ethereum_2022_11_02.xlsx', 'uniswap_ethereum_2022_11_03.xlsx', 'uniswap_ethereum_2022_11_04.xlsx', 'uniswap_ethereum_2022_11_05.xlsx', 'uniswap_ethereum_2022_11_06.xlsx', 'uniswap_ethereum_2022_11_07.xlsx', 'uniswap_ethereum_2022_11_08.xlsx', 'uniswap_ethereum_2022_11_09.xlsx', 'uniswap_ethereum_2022_11_10.xlsx', 'uniswap_ethereum_2022_11_11.xlsx', 'uniswap_ethereum_2022_11_12.xlsx', 'uniswap_ethereum_2022_11_13.xlsx', 'uniswap_ethereum_2022_11_14.xlsx', 'uniswap_ethereum_2022_11_15.xlsx', 'uniswap_ethereum_2022_11_30.xlsx', 'uniswap_ethereum_2022_11_29.xlsx', 'uniswap_ethereum_2022_11_28.xlsx', 'uniswap_ethereum_2022_11_16.xlsx', 'uniswap_ethereum_2022_11_17.xlsx', 'uniswap_ethereum_2022_11_18.xlsx', 'uniswap_ethereum_2022_11_25.xlsx', 'uniswap_ethereum_2022_11_19.xlsx', 'uniswap_ethereum_2022_11_20.xlsx', 'uniswap_ethereum_2022_11_21.xlsx', 'uniswap_ethereum_2022_11_22.xlsx', 'uniswap_ethereum_2022_11_23.xlsx', 'uniswap_ethereum_2022_11
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2022_11_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x00003f5a0241ea0fde6c2e4d9682a444c414a0b89c1b...
# 1  0x0002712e78d3f2cb71a00e6617f79278d267f466e700...
# 2  0x0002c2ccbf8a09d06f26355a3b4c5a70617eefabcf38...
# 3  0x0002c2ccbf8a09d06f26355a3b4c5a70617eefabcf38...
# 4  0x0002f3cdd6b733147b48cf00e741ff4f2a193eea5e6a...
#
#                                       Transaction ID           Timestamp  \
# 0  0x00003f5a0241ea0fde6c2e4d9682a444c414a0b89c1b... 2022-11-01 06:45:23
# 1  0x0002712e78d3f2cb71a00e6617f79278d267f466e700... 2022-11-01 11:26:35
# 2  0x0002c2ccbf8a09d06f26355a3b4c5a70617eefabcf38... 2022-11-01 14:56:11
# 3  0x0002c2ccbf8a09d06f26355a3b4c5a70617eefabcf38... 2022-11-01 14:56:11
# 4  0x0002f3cdd6b733147b48cf00e741ff4f2a193eea5e6a... 2022-11-01 11:39:47
#
#    Timestamp (Unix)                                        Pool  \
# 0        1667310323  0x5b7e3e37a1aa6369386e5939053779abd3597508
# 1        1667327195  0x60594a405d53811d3bc4766596efd80fd545a270
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 44733  0xfff91b57f8a166b7bf3f4609e720dc45f85b6cc09bbf...
# 44734  0xfffaf859509aa4aecc599d7a93543be798a870398e57...
# 44735  0xfffcd87c805d0ef18fa4f9fc997df24fc5251fbfa13d...
# 44736  0xfffd7921db71bd82b922afc4bf0b218ee6f8510626c4...
# 44737  0xfffda59023ed56925d87236059b7483babd4c8a446ae...
#
#                                           Transaction ID           Timestamp  \
# 44733  0xfff91b57f8a166b7bf3f4609e720dc45f85b6cc09bbf... 2022-11-01 20:35:47
# 44734  0xfffaf859509aa4aecc599d7a93543be798a870398e57... 2022-11-01 23:21:11
# 44735  0xfffcd87c805d0ef18fa4f9fc997df24fc5251fbfa13d... 2022-11-01 01:35:35
# 44736  0xfffd7921db71bd82b922afc4bf0b218ee6f8510626c4... 2022-11-01 13:16:47
# 44737  0xfffda59023ed56925d87236059b7483babd4c8a446ae... 2022-11-01 13:07:23
#
#        Timestamp (Unix)                                        Pool  \
# 44733        1667360147  0x11b815efb8f581194ae79006d24e0d814b7697f6
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 30/30 [08:03<00:00, 16.13s/it]

# %%
df_Eth_Nov = df
df_Eth_Nov.tail()
# Out:
#                                                         ID  \
# 1655785  0xfffbf66548e0d5118d5192f261354e8e908fb7a0318e...
# 1655786  0xfffde765f8c6d20e420b65bf223984baac6e16be8cb3...
# 1655787  0xfffea79b0ce62b9b3a1738404156bbc2fafa9991f85a...
# 1655788  0xfffffd2a2975bc4f7d3348911d92a190040e0128816b...
# 1655789  0xfffffd2a2975bc4f7d3348911d92a190040e0128816b...
#
#                                             Transaction ID  \
# 1655785  0xfffbf66548e0d5118d5192f261354e8e908fb7a0318e...
# 1655786  0xfffde765f8c6d20e420b65bf223984baac6e16be8cb3...
# 1655787  0xfffea79b0ce62b9b3a1738404156bbc2fafa9991f85a...
# 1655788  0xfffffd2a2975bc4f7d3348911d92a190040e0128816b...
# 1655789  0xfffffd2a2975bc4f7d3348911d92a190040e0128816b...
#
#                   Timestamp  Timestamp (Unix)  \
# 1655785 2022-11-24 14:04:35        1669327475
# 1655786 2022-11-24 18:20:59        1669342859
# 1655787 2022-11-24 12:14:11        1669320851
# 1655788 2022-11-24 14:39:23        1669329563
# ...

# %%
df_Eth_Nov.to_csv("Eth_Nov.csv")

# %%
df_Eth_Nov = pd.read_csv("Eth_Nov.csv")

# %%
Eth_Amount_Nov = df_Eth_Nov[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Nov.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Nov
# Out:
#                    Timestamp    Amount_USD
# 0        2022-11-01 06:45:23     99.028390
# 1        2022-11-01 11:26:35  13024.445593
# 2        2022-11-01 14:56:11     13.688573
# 3        2022-11-01 14:56:11     13.688520
# 4        2022-11-01 11:39:47   5805.434584
# ...                      ...           ...
# 1655785  2022-11-24 14:04:35    299.146466
# 1655786  2022-11-24 18:20:59  14783.947075
# 1655787  2022-11-24 12:14:11   2385.435863
# 1655788  2022-11-24 14:39:23    119.898185
# 1655789  2022-11-24 14:39:23    119.796371
#
# [1655790 rows x 2 columns]

# %%
Eth_Amount_Nov['Timestamp']=pd.to_datetime(Eth_Amount_Nov['Timestamp'])
Eth_Amount_Nov.dtypes
# Out:
# <ipython-input-29-b3a6d3c86391>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Nov['Timestamp']=pd.to_datetime(Eth_Amount_Nov['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Nov=Eth_Amount_Nov.sort_values(by='Timestamp')
Eth_Amount_Nov
# Out:
#                   Timestamp     Amount_USD
# 40097   2022-11-01 00:00:11       0.000000
# 40098   2022-11-01 00:00:11      90.328491
# 84836   2022-11-01 00:00:11      90.328491
# 84835   2022-11-01 00:00:11       0.000000
# 44181   2022-11-01 00:00:23     875.718691
# ...                     ...            ...
# 975011  2022-11-30 23:59:59    1561.974476
# 970748  2022-11-30 23:59:59   11503.093020
# 1000864 2022-11-30 23:59:59  301887.837075
# 1002819 2022-11-30 23:59:59     116.708218
# 985155  2022-11-30 23:59:59   34536.926745
#
# [1655790 rows x 2 columns]

# %%
Eth_Amount_Nov.to_csv("Eth_Amount_Nov.csv")
