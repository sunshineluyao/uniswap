# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2022/September" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2022/September'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2022_09_01.xlsx', 'uniswap_ethereum_2022_09_02.xlsx', 'uniswap_ethereum_2022_09_03.xlsx', 'uniswap_ethereum_2022_09_04.xlsx', 'uniswap_ethereum_2022_09_05.xlsx', 'uniswap_ethereum_2022_09_06.xlsx', 'uniswap_ethereum_2022_09_07.xlsx', 'uniswap_ethereum_2022_09_08.xlsx', 'uniswap_ethereum_2022_09_09.xlsx', 'uniswap_ethereum_2022_09_10.xlsx', 'uniswap_ethereum_2022_09_11.xlsx', 'uniswap_ethereum_2022_09_12.xlsx', 'uniswap_ethereum_2022_09_13.xlsx', 'uniswap_ethereum_2022_09_14.xlsx', 'uniswap_ethereum_2022_09_15.xlsx', 'uniswap_ethereum_2022_09_16.xlsx', 'uniswap_ethereum_2022_09_17.xlsx', 'uniswap_ethereum_2022_09_18.xlsx', 'uniswap_ethereum_2022_09_19.xlsx', 'uniswap_ethereum_2022_09_20.xlsx', 'uniswap_ethereum_2022_09_21.xlsx', 'uniswap_ethereum_2022_09_22.xlsx', 'uniswap_ethereum_2022_09_23.xlsx', 'uniswap_ethereum_2022_09_24.xlsx', 'uniswap_ethereum_2022_09_25.xlsx', 'uniswap_ethereum_2022_09_30.xlsx', 'uniswap_ethereum_2022_09_26.xlsx', 'uniswap_ethereum_2022_09
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2022_09_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x00022a0ddbc73d221f861225113780a705cc59efcf06...
# 1  0x00030992f64dfbf5498448f972265e25dea20e0a5db4...
# 2  0x00037c2616809727464589723d1fdc4a6ecc5f11d212...
# 3  0x0004c1a388eee27d0fb36d009d4004810e71d286d36a...
# 4  0x00086b52bf95b18fe9a72089f6b552ebe4c9ea0178a9...
#
#                                       Transaction ID           Timestamp  \
# 0  0x00022a0ddbc73d221f861225113780a705cc59efcf06... 2022-09-01 17:09:21
# 1  0x00030992f64dfbf5498448f972265e25dea20e0a5db4... 2022-09-01 11:30:17
# 2  0x00037c2616809727464589723d1fdc4a6ecc5f11d212... 2022-09-01 13:14:50
# 3  0x0004c1a388eee27d0fb36d009d4004810e71d286d36a... 2022-09-01 12:08:44
# 4  0x00086b52bf95b18fe9a72089f6b552ebe4c9ea0178a9... 2022-09-01 06:06:46
#
#    Timestamp (Unix)                                        Pool  \
# 0        1662077361  0x11b815efb8f581194ae79006d24e0d814b7697f6
# 1        1662057017  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 41892  0xfffd9f0f1e62b47284d3833861ed8e5ee716518e0243...
# 41893  0xfffd9f0f1e62b47284d3833861ed8e5ee716518e0243...
# 41894  0xfffe1ab3fdbe85c0b24614ce15c37b3b926362d0ee7a...
# 41895  0xffff8caa85db61d6a5a7884b8760716b15e3f9670240...
# 41896  0xffff901a11410a74c8950737144859ed0ce8beb55913...
#
#                                           Transaction ID           Timestamp  \
# 41892  0xfffd9f0f1e62b47284d3833861ed8e5ee716518e0243... 2022-09-01 20:06:35
# 41893  0xfffd9f0f1e62b47284d3833861ed8e5ee716518e0243... 2022-09-01 20:06:35
# 41894  0xfffe1ab3fdbe85c0b24614ce15c37b3b926362d0ee7a... 2022-09-01 04:24:41
# 41895  0xffff8caa85db61d6a5a7884b8760716b15e3f9670240... 2022-09-01 15:58:04
# 41896  0xffff901a11410a74c8950737144859ed0ce8beb55913... 2022-09-01 03:56:20
#
#        Timestamp (Unix)                                        Pool  \
# 41892        1662087995  0xd3ca35355106cb8bc5fd7c534275509673319d83
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 30/30 [06:13<00:00, 12.44s/it]

# %%
df_Eth_Sep = df
df_Eth_Sep.tail()
# Out:
#                                                         ID  \
# 1443664  0xfffbc03d3c74bfd95c4e5a157e34104b1b888686bc72...
# 1443665  0xfffc96e2a6e18de5748f8cda964e0d2cd63c120fbe68...
# 1443666  0xfffdd5373b8b2623fd7c1e0ee8314e3772ecbdc5a777...
# 1443667  0xfffed43f1a641d592105b5c5db9ff0ede66f4afac302...
# 1443668  0xfffed43f1a641d592105b5c5db9ff0ede66f4afac302...
#
#                                             Transaction ID  \
# 1443664  0xfffbc03d3c74bfd95c4e5a157e34104b1b888686bc72...
# 1443665  0xfffc96e2a6e18de5748f8cda964e0d2cd63c120fbe68...
# 1443666  0xfffdd5373b8b2623fd7c1e0ee8314e3772ecbdc5a777...
# 1443667  0xfffed43f1a641d592105b5c5db9ff0ede66f4afac302...
# 1443668  0xfffed43f1a641d592105b5c5db9ff0ede66f4afac302...
#
#                   Timestamp  Timestamp (Unix)  \
# 1443664 2022-09-28 19:22:35        1664418155
# 1443665 2022-09-28 19:23:47        1664418227
# 1443666 2022-09-28 10:02:47        1664384567
# 1443667 2022-09-28 15:27:59        1664404079
# ...

# %%
df_Eth_Sep.to_csv("Eth_Sep.csv")

# %%
df_Eth_Sep = pd.read_csv("Eth_Sep.csv")

# %%
Eth_Amount_Sep = df_Eth_Sep[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Sep.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Sep
# Out:
#                    Timestamp     Amount_USD
# 0        2022-09-01 17:09:21      47.457715
# 1        2022-09-01 11:30:17     396.890733
# 2        2022-09-01 13:14:50   50017.091288
# 3        2022-09-01 12:08:44     500.969953
# 4        2022-09-01 06:06:46      49.441709
# ...                      ...            ...
# 1443664  2022-09-28 19:22:35     745.685859
# 1443665  2022-09-28 19:23:47  116616.605465
# 1443666  2022-09-28 10:02:47     460.308849
# 1443667  2022-09-28 15:27:59    1469.177072
# 1443668  2022-09-28 15:27:59    1476.655114
#
# [1443669 rows x 2 columns]

# %%
Eth_Amount_Sep['Timestamp']=pd.to_datetime(Eth_Amount_Sep['Timestamp'])
Eth_Amount_Sep.dtypes
# Out:
# <ipython-input-15-87d40b981f7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Sep['Timestamp']=pd.to_datetime(Eth_Amount_Sep['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Sep=Eth_Amount_Sep.sort_values(by='Timestamp')
Eth_Amount_Sep
# Out:
#                   Timestamp    Amount_USD
# 17965   2022-09-01 00:00:04  24530.910450
# 59862   2022-09-01 00:00:04  24530.910450
# 12359   2022-09-01 00:00:10      4.901910
# 60611   2022-09-01 00:00:10  11148.134701
# 37328   2022-09-01 00:00:10   1258.148543
# ...                     ...           ...
# 1241261 2022-09-30 23:59:59   1414.394523
# 1221780 2022-09-30 23:59:59   6727.932107
# 1221779 2022-09-30 23:59:59   6726.252857
# 1249142 2022-09-30 23:59:59    411.414798
# 1220536 2022-09-30 23:59:59   3092.307643
#
# [1443669 rows x 2 columns]

# %%
Eth_Amount_Sep.to_csv("Eth_Amount_Sep.csv")
