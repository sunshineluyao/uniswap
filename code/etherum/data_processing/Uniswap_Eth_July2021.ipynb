# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2021/July" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2021/July'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2021_07_1.xlsx', 'uniswap_ethereum_2021_07_2.xlsx', 'uniswap_ethereum_2021_07_3.xlsx', 'uniswap_ethereum_2021_07_4.xlsx', 'uniswap_ethereum_2021_07_5.xlsx', 'uniswap_ethereum_2021_07_6.xlsx', 'uniswap_ethereum_2021_07_7.xlsx', 'uniswap_ethereum_2021_07_8.xlsx', 'uniswap_ethereum_2021_07_9.xlsx', 'uniswap_ethereum_2021_07_10.xlsx', 'uniswap_ethereum_2021_07_11.xlsx', 'uniswap_ethereum_2021_07_12.xlsx', 'uniswap_ethereum_2021_07_13.xlsx', 'uniswap_ethereum_2021_07_14.xlsx', 'uniswap_ethereum_2021_07_15.xlsx', 'uniswap_ethereum_2021_07_16.xlsx', 'uniswap_ethereum_2021_07_17.xlsx', 'uniswap_ethereum_2021_07_18.xlsx', 'uniswap_ethereum_2021_07_19.xlsx', 'uniswap_ethereum_2021_07_20.xlsx', 'uniswap_ethereum_2021_07_21.xlsx', 'uniswap_ethereum_2021_07_22.xlsx', 'uniswap_ethereum_2021_07_23.xlsx', 'uniswap_ethereum_2021_07_24.xlsx', 'uniswap_ethereum_2021_07_25.xlsx', 'uniswap_ethereum_2021_07_26.xlsx', 'uniswap_ethereum_2021_07_27.xlsx', 'uniswap_ethereum_2021_07_28.xlsx'
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2021_07_1.xlsx")
df1.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                                   ID  \
# 0  0x00004455b7d651b06e966eb4dde618b23df0074b9a42...
# 1  0x000084bc7a511c9c9c85e47f1ffffaca6d88b28654c1...
# 2  0x000165cb96da77c604a56d8d61d6ef33e2c5de63edcf...
# 3  0x000290da5c01253da8552112ee2ec85cd1fa93bfa23a...
# 4  0x000290da5c01253da8552112ee2ec85cd1fa93bfa23a...
#
#                                       Transaction ID           Timestamp  \
# 0  0x00004455b7d651b06e966eb4dde618b23df0074b9a42... 2021-07-01 21:30:02
# 1  0x000084bc7a511c9c9c85e47f1ffffaca6d88b28654c1... 2021-07-01 11:10:11
# 2  0x000165cb96da77c604a56d8d61d6ef33e2c5de63edcf... 2021-07-01 22:58:00
# 3  0x000290da5c01253da8552112ee2ec85cd1fa93bfa23a... 2021-07-01 10:49:24
# 4  0x000290da5c01253da8552112ee2ec85cd1fa93bfa23a... 2021-07-01 10:49:24
#
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 43388  0xfff9d0985d89584b0d2b2cd67e38512f53257aca87dd...
# 43389  0xfff9d0985d89584b0d2b2cd67e38512f53257aca87dd...
# 43390  0xfffb99450b8d43189e6f85fba336f26cf9acac3d676e...
# 43391  0xfffffb57b9e00e60d01cfcf38c2511e64dbd24e4c3a9...
# 43392  0xfffffb57b9e00e60d01cfcf38c2511e64dbd24e4c3a9...
#
#                                           Transaction ID           Timestamp  \
# 43388  0xfff9d0985d89584b0d2b2cd67e38512f53257aca87dd... 2021-07-01 10:00:16
# 43389  0xfff9d0985d89584b0d2b2cd67e38512f53257aca87dd... 2021-07-01 10:00:16
# 43390  0xfffb99450b8d43189e6f85fba336f26cf9acac3d676e... 2021-07-01 22:01:53
# 43391  0xfffffb57b9e00e60d01cfcf38c2511e64dbd24e4c3a9... 2021-07-01 07:56:05
# 43392  0xfffffb57b9e00e60d01cfcf38c2511e64dbd24e4c3a9... 2021-07-01 07:56:05
#
#        Timestamp (Unix)                                        Pool  \
# 43388        1625158816  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   3%|▎         | 1/31 [00:11<05:33, 11.11s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   6%|▋         | 2/31 [00:23<05:36, 11.60s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  10%|▉         | 3/31 [00:37<06:00, 12.88s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ...

# %%
df_Eth_July2021 = df
df_Eth_July2021.tail()
# Out:
#                                                         ID  \
# 1503700  0xfffd132c494553d5c9793a9fa623af5e85c453576d11...
# 1503701  0xfffd132c494553d5c9793a9fa623af5e85c453576d11...
# 1503702  0xfffd9e9fb82752bbf69eedae89a1ad740a37bcc602d4...
# 1503703  0xfffddeb47878170e7ac8d2e77be8aadd4cc39a320b76...
# 1503704  0xffffbf42aa66da7f624ffb8d616918f58191123c0a60...
#
#                                             Transaction ID  \
# 1503700  0xfffd132c494553d5c9793a9fa623af5e85c453576d11...
# 1503701  0xfffd132c494553d5c9793a9fa623af5e85c453576d11...
# 1503702  0xfffd9e9fb82752bbf69eedae89a1ad740a37bcc602d4...
# 1503703  0xfffddeb47878170e7ac8d2e77be8aadd4cc39a320b76...
# 1503704  0xffffbf42aa66da7f624ffb8d616918f58191123c0a60...
#
#                   Timestamp  Timestamp (Unix)  \
# 1503700 2021-07-31 07:52:51        1627743171
# 1503701 2021-07-31 07:52:51        1627743171
# 1503702 2021-07-31 01:04:29        1627718669
# 1503703 2021-07-31 01:13:36        1627719216
# ...

# %%
df_Eth_July2021.to_csv("Eth_July2021.csv")

# %%
df_Eth_July2021 = pd.read_csv("Eth_July2021.csv")

# %%
Eth_Amount_July2021 = df_Eth_July2021[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_July2021.columns =['Timestamp', 'Amount_USD']
Eth_Amount_July2021
# Out:
#                    Timestamp     Amount_USD
# 0        2021-07-01 21:30:02   30332.957891
# 1        2021-07-01 11:10:11   20985.660263
# 2        2021-07-01 22:58:00   17467.920503
# 3        2021-07-01 10:49:24      50.700293
# 4        2021-07-01 10:49:24      50.746895
# ...                      ...            ...
# 1503700  2021-07-31 07:52:51     588.601779
# 1503701  2021-07-31 07:52:51     587.767305
# 1503702  2021-07-31 01:04:29  119433.223597
# 1503703  2021-07-31 01:13:36     708.412128
# 1503704  2021-07-31 02:37:50    3071.119171
#
# [1503705 rows x 2 columns]

# %%
Eth_Amount_July2021['Timestamp']=pd.to_datetime(Eth_Amount_July2021['Timestamp'])
Eth_Amount_July2021.dtypes
# Out:
# <ipython-input-20-6614c38dcf13>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_July2021['Timestamp']=pd.to_datetime(Eth_Amount_July2021['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_July2021=Eth_Amount_July2021.sort_values(by='Timestamp')
Eth_Amount_July2021
# Out:
#                   Timestamp    Amount_USD
# 51851   2021-07-01 00:00:28   1469.430137
# 59956   2021-07-01 00:00:28   2162.824593
# 21968   2021-07-01 00:00:28  49882.902004
# 77742   2021-07-01 00:00:28  17233.215401
# 34896   2021-07-01 00:00:28  30307.820634
# ...                     ...           ...
# 1464486 2021-07-31 23:59:42   4418.704631
# 1464487 2021-07-31 23:59:42   4419.809956
# 1486190 2021-07-31 23:59:42   2585.419721
# 1472116 2021-07-31 23:59:42  18413.372945
# 1472115 2021-07-31 23:59:42  18421.011051
#
# [1503705 rows x 2 columns]

# %%
Eth_Amount_July2021.to_csv("Eth_Amount_July2021.csv")
