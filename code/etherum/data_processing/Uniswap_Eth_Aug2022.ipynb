# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2022/August" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2022/August'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2022_08_03.xlsx', 'uniswap_ethereum_2022_08_04.xlsx', 'uniswap_ethereum_2022_08_05.xlsx', 'uniswap_ethereum_2022_08_06.xlsx', 'uniswap_ethereum_2022_08_07.xlsx', 'uniswap_ethereum_2022_08_08.xlsx', 'uniswap_ethereum_2022_08_09.xlsx', 'uniswap_ethereum_2022_08_10.xlsx', 'uniswap_ethereum_2022_08_11.xlsx', 'uniswap_ethereum_2022_08_12.xlsx', 'uniswap_ethereum_2022_08_13.xlsx', 'uniswap_ethereum_2022_08_14.xlsx', 'uniswap_ethereum_2022_08_15.xlsx', 'uniswap_ethereum_2022_08_16.xlsx', 'uniswap_ethereum_2022_08_17.xlsx', 'uniswap_ethereum_2022_08_18.xlsx', 'uniswap_ethereum_2022_08_19.xlsx', 'uniswap_ethereum_2022_08_20.xlsx', 'uniswap_ethereum_2022_08_22.xlsx', 'uniswap_ethereum_2022_08_23.xlsx', 'uniswap_ethereum_2022_08_24.xlsx', 'uniswap_ethereum_2022_08_25.xlsx', 'uniswap_ethereum_2022_08_26.xlsx', 'uniswap_ethereum_2022_08_31.xlsx', 'uniswap_ethereum_2022_08_27.xlsx', 'uniswap_ethereum_2022_08_28.xlsx', 'uniswap_ethereum_2022_08_29.xlsx', 'uniswap_ethereum_2022_08
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2022_08_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x0006b560f30786067a5ac804243ce1b91e7cf7847cc6...
# 1  0x0007f9bb40d70550afd73a2f152a8130c4e97c81e2fd...
# 2  0x00087a6f6c538785ebec8e44fb12fa59a14b7808d826...
# 3  0x000a841913ee6243ebbac4321c0df8e8da7286db25d7...
# 4  0x000c38bb54dda3b4db45047d798f85c7b21da247cd13...
#
#                                       Transaction ID           Timestamp  \
# 0  0x0006b560f30786067a5ac804243ce1b91e7cf7847cc6... 2022-08-01 12:29:04
# 1  0x0007f9bb40d70550afd73a2f152a8130c4e97c81e2fd... 2022-08-01 04:28:18
# 2  0x00087a6f6c538785ebec8e44fb12fa59a14b7808d826... 2022-08-01 20:38:46
# 3  0x000a841913ee6243ebbac4321c0df8e8da7286db25d7... 2022-08-01 06:40:37
# 4  0x000c38bb54dda3b4db45047d798f85c7b21da247cd13... 2022-08-01 19:26:50
#
#    Timestamp (Unix)                                        Pool  \
# 0        1659382144  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 1        1659353298  0xecca6db8efe28b93af5abc69fa7d8094cbefe139
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 41247  0xfff58721aed16121af8a796925666a578ac63aca8051...
# 41248  0xfff58721aed16121af8a796925666a578ac63aca8051...
# 41249  0xfff91d15f7d65f35cafe4aec283b0e1050cb2c30302d...
# 41250  0xfffb7e9ced475d3cc2dd149340af7f2bc164f7238dd9...
# 41251  0xfffd6d4cfdfff6201be004c8f31b990d23ba3b2df84a...
#
#                                           Transaction ID           Timestamp  \
# 41247  0xfff58721aed16121af8a796925666a578ac63aca8051... 2022-08-01 15:43:32
# 41248  0xfff58721aed16121af8a796925666a578ac63aca8051... 2022-08-01 15:43:32
# 41249  0xfff91d15f7d65f35cafe4aec283b0e1050cb2c30302d... 2022-08-01 13:05:11
# 41250  0xfffb7e9ced475d3cc2dd149340af7f2bc164f7238dd9... 2022-08-01 22:27:02
# 41251  0xfffd6d4cfdfff6201be004c8f31b990d23ba3b2df84a... 2022-08-01 05:58:48
#
#        Timestamp (Unix)                                        Pool  \
# 41247        1659393812  0x8cb8f052e7337573cd59d33bb67b2acbb65e9876
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 31/31 [05:39<00:00, 10.94s/it]

# %%
df_Eth_Aug = df
df_Eth_Aug.tail()
# Out:
#                                                         ID  \
# 1394230  0xfff58721aed16121af8a796925666a578ac63aca8051...
# 1394231  0xfff58721aed16121af8a796925666a578ac63aca8051...
# 1394232  0xfff91d15f7d65f35cafe4aec283b0e1050cb2c30302d...
# 1394233  0xfffb7e9ced475d3cc2dd149340af7f2bc164f7238dd9...
# 1394234  0xfffd6d4cfdfff6201be004c8f31b990d23ba3b2df84a...
#
#                                             Transaction ID  \
# 1394230  0xfff58721aed16121af8a796925666a578ac63aca8051...
# 1394231  0xfff58721aed16121af8a796925666a578ac63aca8051...
# 1394232  0xfff91d15f7d65f35cafe4aec283b0e1050cb2c30302d...
# 1394233  0xfffb7e9ced475d3cc2dd149340af7f2bc164f7238dd9...
# 1394234  0xfffd6d4cfdfff6201be004c8f31b990d23ba3b2df84a...
#
#                   Timestamp  Timestamp (Unix)  \
# 1394230 2022-08-01 15:43:32        1659393812
# 1394231 2022-08-01 15:43:32        1659393812
# 1394232 2022-08-01 13:05:11        1659384311
# 1394233 2022-08-01 22:27:02        1659418022
# ...

# %%
df_Eth_Aug.to_csv("Eth_Aug.csv")

# %%
df_Eth_Aug = pd.read_csv("Eth_Aug.csv")

# %%
Eth_Amount_Aug = df_Eth_Aug[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Aug.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Aug
# Out:
#                    Timestamp    Amount_USD
# 0        2022-08-01 12:29:04   1623.658614
# 1        2022-08-01 04:28:18    991.280285
# 2        2022-08-01 20:38:46    157.596719
# 3        2022-08-01 06:40:37     29.767464
# 4        2022-08-01 19:26:50    500.106239
# ...                      ...           ...
# 1394230  2022-08-01 15:43:32   1000.091832
# 1394231  2022-08-01 15:43:32   1001.408311
# 1394232  2022-08-01 13:05:11    681.893195
# 1394233  2022-08-01 22:27:02  70522.310910
# 1394234  2022-08-01 05:58:48    136.984018
#
# [1394235 rows x 2 columns]

# %%
Eth_Amount_Aug['Timestamp']=pd.to_datetime(Eth_Amount_Aug['Timestamp'])
Eth_Amount_Aug.dtypes
# Out:
# <ipython-input-32-240e0e1f3daf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Aug['Timestamp']=pd.to_datetime(Eth_Amount_Aug['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Aug=Eth_Amount_Aug.sort_values(by='Timestamp')
Eth_Amount_Aug
# Out:
#                   Timestamp    Amount_USD
# 1373096 2022-08-01 00:00:26   4131.353071
# 1360864 2022-08-01 00:00:26     16.412065
# 1367281 2022-08-01 00:00:26     43.418512
# 1392182 2022-08-01 00:00:26   3384.271500
# 21987   2022-08-01 00:00:26    878.038173
# ...                     ...           ...
# 1076332 2022-08-31 23:59:38   1052.288520
# 1062256 2022-08-31 23:59:38  26229.186025
# 1076333 2022-08-31 23:59:38   1050.973385
# 1051585 2022-08-31 23:59:38     77.808574
# 1067626 2022-08-31 23:59:38    168.803978
#
# [1394235 rows x 2 columns]

# %%
Eth_Amount_Aug.to_csv("Eth_Amount_Aug.csv")
