# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2021/September" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2021/September'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2021_09_1.xlsx', 'uniswap_ethereum_2021_09_2.xlsx', 'uniswap_ethereum_2021_09_3.xlsx', 'uniswap_ethereum_2021_09_4.xlsx', 'uniswap_ethereum_2021_09_5.xlsx', 'uniswap_ethereum_2021_09_6.xlsx', 'uniswap_ethereum_2021_09_7.xlsx', 'uniswap_ethereum_2021_09_8.xlsx', 'uniswap_ethereum_2021_09_9.xlsx', 'uniswap_ethereum_2021_09_10.xlsx', 'uniswap_ethereum_2021_09_11.xlsx', 'uniswap_ethereum_2021_09_12.xlsx', 'uniswap_ethereum_2021_09_13.xlsx', 'uniswap_ethereum_2021_09_14.xlsx', 'uniswap_ethereum_2021_09_15.xlsx', 'uniswap_ethereum_2021_09_16.xlsx', 'uniswap_ethereum_2021_09_17.xlsx', 'uniswap_ethereum_2021_09_18.xlsx', 'uniswap_ethereum_2021_09_19.xlsx', 'uniswap_ethereum_2021_09_20.xlsx', 'uniswap_ethereum_2021_09_21.xlsx', 'uniswap_ethereum_2021_09_22.xlsx', 'uniswap_ethereum_2021_09_23.xlsx', 'uniswap_ethereum_2021_09_24.xlsx', 'uniswap_ethereum_2021_09_25.xlsx', 'uniswap_ethereum_2021_09_26.xlsx', 'uniswap_ethereum_2021_09_27.xlsx', 'uniswap_ethereum_2021_09_28.xlsx'
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2021_09_1.xlsx")
df1.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                                   ID  \
# 0  0x00003974977da3e8b849578394e64acc7ef99b055b26...
# 1  0x0000b62dedbd40d079b60b23c0f86735007366aa8aa2...
# 2  0x000506d5aac5b638a39eca97eff3bee7dec136ba8001...
# 3  0x0006248bcda278275e2d2a7af90ba17f202bb9d93a78...
# 4  0x0009d99bc1f469061ea665ec1976558335885c7dd2bc...
#
#                                       Transaction ID           Timestamp  \
# 0  0x00003974977da3e8b849578394e64acc7ef99b055b26... 2021-09-01 12:58:13
# 1  0x0000b62dedbd40d079b60b23c0f86735007366aa8aa2... 2021-09-01 05:34:49
# 2  0x000506d5aac5b638a39eca97eff3bee7dec136ba8001... 2021-09-01 23:38:41
# 3  0x0006248bcda278275e2d2a7af90ba17f202bb9d93a78... 2021-09-01 19:26:34
# 4  0x0009d99bc1f469061ea665ec1976558335885c7dd2bc... 2021-09-01 12:34:16
#
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 31305  0xfff8ee045a0d4ef89832f6e157f39f08bc0e2ba909e3...
# 31306  0xfff8ee045a0d4ef89832f6e157f39f08bc0e2ba909e3...
# 31307  0xfff9a610e005111c9b4ee4124397604d3a76a807cd70...
# 31308  0xfffb885fa645c42e7a33a0807694b9c31753c971833f...
# 31309  0xfffcc1ae966953772f1c6e4331fff5c448619dbf7dc5...
#
#                                           Transaction ID           Timestamp  \
# 31305  0xfff8ee045a0d4ef89832f6e157f39f08bc0e2ba909e3... 2021-09-01 01:10:55
# 31306  0xfff8ee045a0d4ef89832f6e157f39f08bc0e2ba909e3... 2021-09-01 01:10:55
# 31307  0xfff9a610e005111c9b4ee4124397604d3a76a807cd70... 2021-09-01 14:49:27
# 31308  0xfffb885fa645c42e7a33a0807694b9c31753c971833f... 2021-09-01 19:28:02
# 31309  0xfffcc1ae966953772f1c6e4331fff5c448619dbf7dc5... 2021-09-01 14:49:06
#
#        Timestamp (Unix)                                        Pool  \
# 31305        1630483855  0x11b815efb8f581194ae79006d24e0d814b7697f6
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   3%|▎         | 1/30 [00:08<04:10,  8.64s/it]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   7%|▋         | 2/30 [00:18<04:27,  9.55s/it]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  10%|█         | 3/30 [00:29<04:26,  9.87s/it]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ...

# %%
df_Eth_Sep2021 = df
df_Eth_Sep2021.tail()
# Out:
#                                                         ID  \
# 1072399  0xfff91d9d905fc6ac8ebed7c57d7d43267fdf67841848...
# 1072400  0xfffa56cc4e29f657f13c3134d8c515c2dc0bdafb021c...
# 1072401  0xfffbe37a478ec1b59250049e156b226d8f0051e1695e...
# 1072402  0xfffbe37a478ec1b59250049e156b226d8f0051e1695e...
# 1072403  0xfffc79c0bc207af112c418f7dbeae532fbd9064e6444...
#
#                                             Transaction ID  \
# 1072399  0xfff91d9d905fc6ac8ebed7c57d7d43267fdf67841848...
# 1072400  0xfffa56cc4e29f657f13c3134d8c515c2dc0bdafb021c...
# 1072401  0xfffbe37a478ec1b59250049e156b226d8f0051e1695e...
# 1072402  0xfffbe37a478ec1b59250049e156b226d8f0051e1695e...
# 1072403  0xfffc79c0bc207af112c418f7dbeae532fbd9064e6444...
#
#                   Timestamp  Timestamp (Unix)  \
# 1072399 2021-09-30 10:13:41        1633022021
# 1072400 2021-09-30 14:49:20        1633038560
# 1072401 2021-09-30 19:34:09        1633055649
# 1072402 2021-09-30 19:34:09        1633055649
# ...

# %%
df_Eth_Sep2021.to_csv("Eth_Sep2021.csv")

# %%
df_Eth_Sep2021 = pd.read_csv("Eth_Sep2021.csv")
# Out:
# <ipython-input-13-464a7ba8a7b6>:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Eth_Sep2021 = pd.read_csv("Eth_Sep2021.csv")

# %%
Eth_Amount_Sep2021 = df_Eth_Sep2021[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Sep2021.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Sep2021
# Out:
#                    Timestamp     Amount_USD
# 0        2021-09-01 12:58:13  118882.623317
# 1        2021-09-01 05:34:49     287.650816
# 2        2021-09-01 23:38:41   19639.503429
# 3        2021-09-01 19:26:34     865.159534
# 4        2021-09-01 12:34:16    1311.505858
# ...                      ...            ...
# 1072399  2021-09-30 10:13:41  187314.194959
# 1072400  2021-09-30 14:49:20    1488.407974
# 1072401  2021-09-30 19:34:09    8807.465664
# 1072402  2021-09-30 19:34:09    8820.759626
# 1072403  2021-09-30 23:25:08       4.651187
#
# [1072404 rows x 2 columns]

# %%
Eth_Amount_Sep2021['Timestamp']=pd.to_datetime(Eth_Amount_Sep2021['Timestamp'])
Eth_Amount_Sep2021.dtypes
# Out:
# <ipython-input-16-bae809b9ef78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Sep2021['Timestamp']=pd.to_datetime(Eth_Amount_Sep2021['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Sep2021=Eth_Amount_Sep2021.sort_values(by='Timestamp')
Eth_Amount_Sep2021
# Out:
#                   Timestamp   Amount_USD
# 38974   2021-09-01 00:00:12   919.511882
# 7664    2021-09-01 00:00:12   919.511882
# 9196    2021-09-01 00:00:12  5717.824986
# 38973   2021-09-01 00:00:12   918.342881
# 40506   2021-09-01 00:00:12  5717.824986
# ...                     ...          ...
# 1052145 2021-09-30 23:59:44  8058.843854
# 1045634 2021-09-30 23:59:44  1001.989375
# 1055848 2021-09-30 23:59:44   814.870878
# 1051579 2021-09-30 23:59:44  3735.000000
# 1066977 2021-09-30 23:59:44  2716.236258
#
# [1072404 rows x 2 columns]

# %%
Eth_Amount_Sep2021.to_csv("Eth_Amount_Sep2021.csv")
