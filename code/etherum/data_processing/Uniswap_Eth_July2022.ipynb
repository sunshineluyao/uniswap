# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2022/July" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2022/July'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2022_07_01.xlsx', 'uniswap_ethereum_2022_07_02.xlsx', 'uniswap_ethereum_2022_07_03.xlsx', 'uniswap_ethereum_2022_07_04.xlsx', 'uniswap_ethereum_2022_07_31.xlsx', 'uniswap_ethereum_2022_07_05.xlsx', 'uniswap_ethereum_2022_07_30.xlsx', 'uniswap_ethereum_2022_07_06.xlsx', 'uniswap_ethereum_2022_07_29.xlsx', 'uniswap_ethereum_2022_07_28.xlsx', 'uniswap_ethereum_2022_07_27.xlsx', 'uniswap_ethereum_2022_07_07.xlsx', 'uniswap_ethereum_2022_07_26.xlsx', 'uniswap_ethereum_2022_07_08.xlsx', 'uniswap_ethereum_2022_07_25.xlsx', 'uniswap_ethereum_2022_07_24.xlsx', 'uniswap_ethereum_2022_07_09.xlsx', 'uniswap_ethereum_2022_07_23.xlsx', 'uniswap_ethereum_2022_07_22.xlsx', 'uniswap_ethereum_2022_07_21.xlsx', 'uniswap_ethereum_2022_07_20.xlsx', 'uniswap_ethereum_2022_07_19.xlsx', 'uniswap_ethereum_2022_07_18.xlsx', 'uniswap_ethereum_2022_07_17.xlsx', 'uniswap_ethereum_2022_07_16.xlsx', 'uniswap_ethereum_2022_07_11.xlsx', 'uniswap_ethereum_2022_07_13.xlsx', 'uniswap_ethereum_2022_07
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2022_07_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x0000c4e1dc9f28a1d53177dcc15cb555e301e43c8421...
# 1  0x00087357ad369c52ea7e3919b22b560296089f52749d...
# 2  0x000ba94d9e2a4709ae1350fc397f8a455ed1b39a543a...
# 3  0x000ebb116af061ce5d5e9d4b1a206af0264bf7dc07cb...
# 4  0x0015588ed423f5444aba93cc44a0db70cb9f99c8093d...
#
#                                       Transaction ID           Timestamp  \
# 0  0x0000c4e1dc9f28a1d53177dcc15cb555e301e43c8421... 2022-07-01 09:05:46
# 1  0x00087357ad369c52ea7e3919b22b560296089f52749d... 2022-07-01 15:08:08
# 2  0x000ba94d9e2a4709ae1350fc397f8a455ed1b39a543a... 2022-07-01 17:39:15
# 3  0x000ebb116af061ce5d5e9d4b1a206af0264bf7dc07cb... 2022-07-01 05:34:35
# 4  0x0015588ed423f5444aba93cc44a0db70cb9f99c8093d... 2022-07-01 23:20:27
#
#    Timestamp (Unix)                                        Pool  \
# 0        1656691546  0xe15e6583425700993bd08f51bf6e7b73cd5da91b
# 1        1656713288  0xeb5c52e8af57334fab0b5f3d888990c108545527
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 33924  0xfff9edacc6d66c6afeec346382bb77517fa8c0d9a3eb...
# 33925  0xfffbd600bb3425b292c8446ccff4653e5487270f2d0b...
# 33926  0xfffbd600bb3425b292c8446ccff4653e5487270f2d0b...
# 33927  0xfffc409a95184cba139c9fc6d3ecf06f0040143eeaf7...
# 33928  0xffff5600eece0e74479871a126015133fce92857d22e...
#
#                                           Transaction ID           Timestamp  \
# 33924  0xfff9edacc6d66c6afeec346382bb77517fa8c0d9a3eb... 2022-07-01 17:57:04
# 33925  0xfffbd600bb3425b292c8446ccff4653e5487270f2d0b... 2022-07-01 16:39:20
# 33926  0xfffbd600bb3425b292c8446ccff4653e5487270f2d0b... 2022-07-01 16:39:20
# 33927  0xfffc409a95184cba139c9fc6d3ecf06f0040143eeaf7... 2022-07-01 01:49:04
# 33928  0xffff5600eece0e74479871a126015133fce92857d22e... 2022-07-01 01:30:49
#
#        Timestamp (Unix)                                        Pool  \
# 33924        1656723424  0x4585fe77225b41b697c938b018e2ac67ac5a20c0
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 30/30 [05:46<00:00, 11.53s/it]

# %%
df_Eth_July = df
df_Eth_July.tail()
# Out:
#                                                         ID  \
# 1212171  0xfff36b29c4592bcbe0d4954d6ebcad0e03c4a671565b...
# 1212172  0xfff3a55fb0b77887219b100c4fb796c574545fa097c6...
# 1212173  0xfff3aec235158d809a0c978732e0acb3eb5d769cce99...
# 1212174  0xfff54ffc49bb1f6c2ca279e3c429260b9d0e976e3d4c...
# 1212175  0xffff726d8b029f7b291fde69ae922e7b6ed1c1ee35b4...
#
#                                             Transaction ID  \
# 1212171  0xfff36b29c4592bcbe0d4954d6ebcad0e03c4a671565b...
# 1212172  0xfff3a55fb0b77887219b100c4fb796c574545fa097c6...
# 1212173  0xfff3aec235158d809a0c978732e0acb3eb5d769cce99...
# 1212174  0xfff54ffc49bb1f6c2ca279e3c429260b9d0e976e3d4c...
# 1212175  0xffff726d8b029f7b291fde69ae922e7b6ed1c1ee35b4...
#
#                   Timestamp  Timestamp (Unix)  \
# 1212171 2022-07-10 22:21:55        1657516915
# 1212172 2022-07-10 08:16:05        1657466165
# 1212173 2022-07-10 08:06:14        1657465574
# 1212174 2022-07-10 15:31:25        1657492285
# ...

# %%
df_Eth_July.to_csv("Eth_July.csv")

# %%
df_Eth_July = pd.read_csv("Eth_July.csv")

# %%
Eth_Amount_July = df_Eth_July[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_July.columns =['Timestamp', 'Amount_USD']
Eth_Amount_July
# Out:
#                    Timestamp     Amount_USD
# 0        2022-07-01 09:05:46    5002.030379
# 1        2022-07-01 15:08:08     110.850181
# 2        2022-07-01 17:39:15  245668.973281
# 3        2022-07-01 05:34:35   99375.021610
# 4        2022-07-01 23:20:27    1526.302393
# ...                      ...            ...
# 1212171  2022-07-10 22:21:55    9969.906703
# 1212172  2022-07-10 08:16:05     144.945648
# 1212173  2022-07-10 08:06:14   92939.038670
# 1212174  2022-07-10 15:31:25    7624.929793
# 1212175  2022-07-10 10:37:55    5067.066145
#
# [1212176 rows x 2 columns]

# %%
Eth_Amount_July['Timestamp']=pd.to_datetime(Eth_Amount_July['Timestamp'])
Eth_Amount_July.dtypes
# Out:
# <ipython-input-15-33c4f7e148dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_July['Timestamp']=pd.to_datetime(Eth_Amount_July['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_July=Eth_Amount_July.sort_values(by='Timestamp')
Eth_Amount_July
# Out:
#                  Timestamp    Amount_USD
# 61787  2022-07-01 00:00:41    999.921938
# 26118  2022-07-01 00:00:41    108.619865
# 62274  2022-07-01 00:00:41    105.433200
# 38538  2022-07-01 00:00:41    514.543563
# 26117  2022-07-01 00:00:41    108.783368
# ...                    ...           ...
# 165827 2022-07-31 23:59:46    978.595818
# 193537 2022-07-31 23:59:46   2440.751589
# 165828 2022-07-31 23:59:46    977.191637
# 185574 2022-07-31 23:59:46    791.853685
# 176407 2022-07-31 23:59:46  58719.686769
#
# [1212176 rows x 2 columns]

# %%
Eth_Amount_July.to_csv("Eth_Amount_July.csv")
