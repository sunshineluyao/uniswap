# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2021/October" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2021/October'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2021_10_1.xlsx', 'uniswap_ethereum_2021_10_2.xlsx', 'uniswap_ethereum_2021_10_3.xlsx', 'uniswap_ethereum_2021_10_4.xlsx', 'uniswap_ethereum_2021_10_5.xlsx', 'uniswap_ethereum_2021_10_6.xlsx', 'uniswap_ethereum_2021_10_7.xlsx', 'uniswap_ethereum_2021_10_8.xlsx', 'uniswap_ethereum_2021_10_9.xlsx', 'uniswap_ethereum_2021_10_10.xlsx', 'uniswap_ethereum_2021_10_11.xlsx', 'uniswap_ethereum_2021_10_12.xlsx', 'uniswap_ethereum_2021_10_13.xlsx', 'uniswap_ethereum_2021_10_14.xlsx', 'uniswap_ethereum_2021_10_15.xlsx', 'uniswap_ethereum_2021_10_16.xlsx', 'uniswap_ethereum_2021_10_17.xlsx', 'uniswap_ethereum_2021_10_18.xlsx', 'uniswap_ethereum_2021_10_19.xlsx', 'uniswap_ethereum_2021_10_20.xlsx', 'uniswap_ethereum_2021_10_26.xlsx', 'uniswap_ethereum_2021_10_21.xlsx', 'uniswap_ethereum_2021_10_22.xlsx', 'uniswap_ethereum_2021_10_27.xlsx', 'uniswap_ethereum_2021_10_23.xlsx', 'uniswap_ethereum_2021_10_28.xlsx', 'uniswap_ethereum_2021_10_24.xlsx', 'uniswap_ethereum_2021_10_29.xlsx'
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2021_10_1.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x0006a79a8a5c06585c37a98086c071ad0be5ebfc0cba...
# 1  0x0006a9ab5c02487f0deaa4e6e568947a37d6e82cd1b5...
# 2  0x00077f5ed83d394038822ebf3a8162a6c560bf639fbc...
# 3  0x000f44faf541355c22450e1d01b090d47a59a912ba57...
# 4  0x0012a4e88b9724a235cf828cb5e835b8c91d9024afef...
#
#                                       Transaction ID           Timestamp  \
# 0  0x0006a79a8a5c06585c37a98086c071ad0be5ebfc0cba... 2021-10-01 13:06:13
# 1  0x0006a9ab5c02487f0deaa4e6e568947a37d6e82cd1b5... 2021-10-01 21:42:16
# 2  0x00077f5ed83d394038822ebf3a8162a6c560bf639fbc... 2021-10-01 03:55:47
# 3  0x000f44faf541355c22450e1d01b090d47a59a912ba57... 2021-10-01 02:12:29
# 4  0x0012a4e88b9724a235cf828cb5e835b8c91d9024afef... 2021-10-01 08:04:38
#
#    Timestamp (Unix)                                        Pool  \
# 0        1633118773  0xe744f5e2edfdcb9fdb43b288ecb8b21c8487e888
# 1        1633149736  0xefbd546647fda46067225bd0221e08ba91071584
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 34070  0xfff8a081e96d4bb689b4bc1d64686db5123fb022168d...
# 34071  0xfffac7b6920c8345c7fd32be934e5cf0a1e9b8c0d400...
# 34072  0xfffba5fb649ed5614e00d2fe8de07b0afd1a14d9f912...
# 34073  0xfffd05e5720925768e61f51c54119106dd4f61f91552...
# 34074  0xfffde906df97bd3dfefddb86d711b79da573c7dc1d49...
#
#                                           Transaction ID           Timestamp  \
# 34070  0xfff8a081e96d4bb689b4bc1d64686db5123fb022168d... 2021-10-01 18:22:58
# 34071  0xfffac7b6920c8345c7fd32be934e5cf0a1e9b8c0d400... 2021-10-01 03:40:40
# 34072  0xfffba5fb649ed5614e00d2fe8de07b0afd1a14d9f912... 2021-10-01 03:12:57
# 34073  0xfffd05e5720925768e61f51c54119106dd4f61f91552... 2021-10-01 13:43:01
# 34074  0xfffde906df97bd3dfefddb86d711b79da573c7dc1d49... 2021-10-01 12:56:36
#
#        Timestamp (Unix)                                        Pool  \
# 34070        1633137778  0x0cfbed8f2248d2735203f602be0cae5a3131ec68
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#  65%|██████▍   | 20/31 [03:48<02:14, 12.24s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  74%|███████▍  | 23/31 [04:26<01:37, 12.23s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  81%|████████  | 25/31 [04:51<01:14, 12.41s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  87%|████████▋ | 27/31 [05:17<00:50, 12.69s/it]/usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ...

# %%
df_Eth_Oct2021 = df
df_Eth_Oct2021.tail()
# Out:
#                                                         ID  \
# 1145798  0xfff77308d85c18c083a29571bf7c2471e729c5120043...
# 1145799  0xfff9a28342b9f6bb7e71a55caf2afb07019407e26753...
# 1145800  0xfffc8dc3e7dd8227b7e10a80eb23cb7b8ec56269ddfa...
# 1145801  0xfffce78c8d5b3ac5e6a850f2081508f501e47d3dd312...
# 1145802  0xfffeeb8d90c7bd33ba86f5604bf421f269126c0a61e9...
#
#                                             Transaction ID  \
# 1145798  0xfff77308d85c18c083a29571bf7c2471e729c5120043...
# 1145799  0xfff9a28342b9f6bb7e71a55caf2afb07019407e26753...
# 1145800  0xfffc8dc3e7dd8227b7e10a80eb23cb7b8ec56269ddfa...
# 1145801  0xfffce78c8d5b3ac5e6a850f2081508f501e47d3dd312...
# 1145802  0xfffeeb8d90c7bd33ba86f5604bf421f269126c0a61e9...
#
#                   Timestamp  Timestamp (Unix)  \
# 1145798 2021-10-31 07:58:45        1635692325
# 1145799 2021-10-31 15:02:48        1635717768
# 1145800 2021-10-31 04:19:28        1635679168
# 1145801 2021-10-31 01:25:33        1635668733
# ...

# %%
df_Eth_Oct2021.to_csv("Eth_Oct2021.csv")

# %%
df_Eth_Oct2021 = pd.read_csv("Eth_Oct2021.csv")

# %%
Eth_Amount_Oct2021 = df_Eth_Oct2021[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Oct2021.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Oct2021
# Out:
#                    Timestamp    Amount_USD
# 0        2021-10-01 13:06:13     65.963913
# 1        2021-10-01 21:42:16   2812.761974
# 2        2021-10-01 03:55:47   1242.051237
# 3        2021-10-01 02:12:29   6233.777550
# 4        2021-10-01 08:04:38     55.351216
# ...                      ...           ...
# 1145798  2021-10-31 07:58:45  14856.009200
# 1145799  2021-10-31 15:02:48    839.380233
# 1145800  2021-10-31 04:19:28   4086.774990
# 1145801  2021-10-31 01:25:33   5707.451245
# 1145802  2021-10-31 15:34:57   1011.584407
#
# [1145803 rows x 2 columns]

# %%
Eth_Amount_Oct2021['Timestamp']=pd.to_datetime(Eth_Amount_Oct2021['Timestamp'])
Eth_Amount_Oct2021.dtypes
# Out:
# <ipython-input-16-a78663d966b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Oct2021['Timestamp']=pd.to_datetime(Eth_Amount_Oct2021['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Oct2021=Eth_Amount_Oct2021.sort_values(by='Timestamp')
Eth_Amount_Oct2021
# Out:
#                   Timestamp    Amount_USD
# 56083   2021-10-01 00:00:23  26224.962620
# 13473   2021-10-01 00:00:23   7154.652947
# 15826   2021-10-01 00:00:23  19864.680249
# 65523   2021-10-01 00:00:23  75451.007179
# 49901   2021-10-01 00:00:23  19864.680249
# ...                     ...           ...
# 1126611 2021-10-31 23:59:35   2872.891281
# 1121789 2021-10-31 23:59:35     42.416468
# 1129179 2021-10-31 23:59:35    424.164677
# 1121724 2021-10-31 23:59:35  10604.116925
# 1110357 2021-10-31 23:59:35      8.409065
#
# [1145803 rows x 2 columns]

# %%
Eth_Amount_Oct2021.to_csv("Eth_Amount_Oct2021.csv")
