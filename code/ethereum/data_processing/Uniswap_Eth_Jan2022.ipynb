# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2022/January" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2022/January'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2022_01_01.xlsx', 'uniswap_ethereum_2022_01_02.xlsx', 'uniswap_ethereum_2022_01_03.xlsx', 'uniswap_ethereum_2022_01_04.xlsx', 'uniswap_ethereum_2022_01_05.xlsx', 'uniswap_ethereum_2022_01_06.xlsx', 'uniswap_ethereum_2022_01_07.xlsx', 'uniswap_ethereum_2022_01_08.xlsx', 'uniswap_ethereum_2022_01_09.xlsx', 'uniswap_ethereum_2022_01_10.xlsx', 'uniswap_ethereum_2022_01_11.xlsx', 'uniswap_ethereum_2022_01_12.xlsx', 'uniswap_ethereum_2022_01_13.xlsx', 'uniswap_ethereum_2022_01_14.xlsx', 'uniswap_ethereum_2022_01_15.xlsx', 'uniswap_ethereum_2022_01_16.xlsx', 'uniswap_ethereum_2022_01_17.xlsx', 'uniswap_ethereum_2022_01_18.xlsx', 'uniswap_ethereum_2022_01_19.xlsx', 'uniswap_ethereum_2022_01_20.xlsx', 'uniswap_ethereum_2022_01_21.xlsx', 'uniswap_ethereum_2022_01_22.xlsx', 'uniswap_ethereum_2022_01_23.xlsx', 'uniswap_ethereum_2022_01_24.xlsx', 'uniswap_ethereum_2022_01_25.xlsx', 'uniswap_ethereum_2022_01_26.xlsx', 'uniswap_ethereum_2022_01_27.xlsx', 'uniswap_ethereum_2022_01
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2022_01_01.xlsx")
df1.head()
# Out:
#                                                   ID  \
# 0  0x000440bab4bf394a73828544635f86b5bc60578e899b...
# 1  0x000440bab4bf394a73828544635f86b5bc60578e899b...
# 2  0x000498fc2aa18038bcd370da85191a6a2855bf4b0ecb...
# 3  0x000498fc2aa18038bcd370da85191a6a2855bf4b0ecb...
# 4  0x00082e69587e986a06b035c517db60a5d7f2c174e4dc...
#
#                                       Transaction ID           Timestamp  \
# 0  0x000440bab4bf394a73828544635f86b5bc60578e899b... 2022-01-01 06:33:45
# 1  0x000440bab4bf394a73828544635f86b5bc60578e899b... 2022-01-01 06:33:45
# 2  0x000498fc2aa18038bcd370da85191a6a2855bf4b0ecb... 2022-01-01 07:27:49
# 3  0x000498fc2aa18038bcd370da85191a6a2855bf4b0ecb... 2022-01-01 07:27:49
# 4  0x00082e69587e986a06b035c517db60a5d7f2c174e4dc... 2022-01-01 02:24:45
#
#    Timestamp (Unix)                                        Pool  \
# 0        1641047625  0x940785e36fc554cb116d2a3df015aa9660b3c411
# 1        1641047625  0x11b815efb8f581194ae79006d24e0d814b7697f6
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 31974  0xffee31d2bdb01efa539a5f39d727ba28296faa26abb6...
# 31975  0xfff5f47fa26bcb55c43fa72dc4fd849d1f3482b4ff26...
# 31976  0xfffdf21f017377a6fa5f5dfe2124afd257174e0ca9eb...
# 31977  0xffffae3b0f10bc4735d8a651c7d44943e28d41388055...
# 31978  0xffffc1ced2099da6017fb7cbfc42a9c191e4e4c69d24...
#
#                                           Transaction ID           Timestamp  \
# 31974  0xffee31d2bdb01efa539a5f39d727ba28296faa26abb6... 2022-01-01 02:38:00
# 31975  0xfff5f47fa26bcb55c43fa72dc4fd849d1f3482b4ff26... 2022-01-01 18:26:47
# 31976  0xfffdf21f017377a6fa5f5dfe2124afd257174e0ca9eb... 2022-01-01 21:05:02
# 31977  0xffffae3b0f10bc4735d8a651c7d44943e28d41388055... 2022-01-01 13:14:28
# 31978  0xffffc1ced2099da6017fb7cbfc42a9c191e4e4c69d24... 2022-01-01 22:20:33
#
#        Timestamp (Unix)                                        Pool  \
# 31974        1641033480  0x60a6b23a7a87c5ce9e3f81c869691f784b18a704
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
# 100%|██████████| 31/31 [05:45<00:00, 11.15s/it]

# %%
df_Eth_Jan = df
df_Eth_Jan.tail()
# Out:
#                                                         ID  \
# 1098172  0xfff90aee2bff4677772b3a5f87e1ce023310c7fd9b07...
# 1098173  0xfffa1600f9a57f6a518749dc61f9a968782f8a18941a...
# 1098174  0xfffc3d67cf7d0c8ab44f3de12567984ee0095c44bb82...
# 1098175  0xfffc54dde609422e42821464a43c825c4c4e1a3d451f...
# 1098176  0xfffe4a462fdfc3c84817baabd40197a04ec5d8424c84...
#
#                                             Transaction ID  \
# 1098172  0xfff90aee2bff4677772b3a5f87e1ce023310c7fd9b07...
# 1098173  0xfffa1600f9a57f6a518749dc61f9a968782f8a18941a...
# 1098174  0xfffc3d67cf7d0c8ab44f3de12567984ee0095c44bb82...
# 1098175  0xfffc54dde609422e42821464a43c825c4c4e1a3d451f...
# 1098176  0xfffe4a462fdfc3c84817baabd40197a04ec5d8424c84...
#
#                   Timestamp  Timestamp (Unix)  \
# 1098172 2022-01-31 11:21:11        1643656871
# 1098173 2022-01-31 04:22:18        1643631738
# 1098174 2022-01-31 00:38:30        1643618310
# 1098175 2022-01-31 04:10:46        1643631046
# ...

# %%
df_Eth_Jan.to_csv("Eth_Jan.csv")

# %%
df_Eth_Jan = pd.read_csv("Eth_Jan.csv")

# %%
Eth_Amount_Jan = df_Eth_Jan[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Jan.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Jan
# Out:
#                    Timestamp     Amount_USD
# 0        2022-01-01 06:33:45    1001.026870
# 1        2022-01-01 06:33:45    1000.261345
# 2        2022-01-01 07:27:49  203963.802523
# 3        2022-01-01 07:27:49  204118.498736
# 4        2022-01-01 02:24:45  449607.234481
# ...                      ...            ...
# 1098172  2022-01-31 11:21:11    3361.733175
# 1098173  2022-01-31 04:22:18     551.453770
# 1098174  2022-01-31 00:38:30     353.949566
# 1098175  2022-01-31 04:10:46  113362.102449
# 1098176  2022-01-31 08:17:13   98243.617343
#
# [1098177 rows x 2 columns]

# %%
Eth_Amount_Jan['Timestamp']=pd.to_datetime(Eth_Amount_Jan['Timestamp'])
Eth_Amount_Jan.dtypes
# Out:
# <ipython-input-29-e55d5b6b27ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Jan['Timestamp']=pd.to_datetime(Eth_Amount_Jan['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Jan=Eth_Amount_Jan.sort_values(by='Timestamp')
Eth_Amount_Jan
# Out:
#                   Timestamp    Amount_USD
# 13284   2022-01-01 00:00:01    259.822822
# 46971   2022-01-01 00:00:01  29518.530567
# 14990   2022-01-01 00:00:01  29551.535234
# 14991   2022-01-01 00:00:01  29536.194049
# 14992   2022-01-01 00:00:01  29518.530567
# ...                     ...           ...
# 1087287 2022-01-31 23:59:52    850.523912
# 1087288 2022-01-31 23:59:52    906.044505
# 1093891 2022-01-31 23:59:52  19906.959877
# 1084141 2022-01-31 23:59:52   2556.950411
# 1078118 2022-01-31 23:59:52   1248.558108
#
# [1098177 rows x 2 columns]

# %%
Eth_Amount_Jan.to_csv("Eth_Amount_Jan.csv")
