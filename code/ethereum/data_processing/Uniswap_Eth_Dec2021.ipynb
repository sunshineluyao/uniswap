# %% [markdown]
# please mount google drive before you begin

# %% [markdown]
# # Part I: Set-up and Data Processing

# %%
cd /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth
# Out:
# /content/drive/MyDrive/DEX_Uniswap_Layer2/Eth

# %%
pwd
# Out:
# '/content/drive/MyDrive/DEX_Uniswap_Layer2/Eth'

# %%
# importing pandas libraries and 
# glob module
import pandas as pd

# %%
#@title path
data = "/content/drive/MyDrive/all_pool_uniswap/Eth/2021/December" #@param {type:"string"}

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/all_pool_uniswap/Eth/2021/December'

# list file and directories
res = os.listdir(dir_path)
print(res)
# Out:
# ['uniswap_ethereum_2021_12_1.xlsx', 'uniswap_ethereum_2021_12_2.xlsx', 'uniswap_ethereum_2021_12_3.xlsx', 'uniswap_ethereum_2021_12_4.xlsx', 'uniswap_ethereum_2021_12_5.xlsx', 'uniswap_ethereum_2021_12_6.xlsx', 'uniswap_ethereum_2021_12_7.xlsx', 'uniswap_ethereum_2021_12_31.xlsx', 'uniswap_ethereum_2021_12_8.xlsx', 'uniswap_ethereum_2021_12_9.xlsx', 'uniswap_ethereum_2021_12_10.xlsx', 'uniswap_ethereum_2021_12_30.xlsx', 'uniswap_ethereum_2021_12_11.xlsx', 'uniswap_ethereum_2021_12_12.xlsx', 'uniswap_ethereum_2021_12_29.xlsx', 'uniswap_ethereum_2021_12_13.xlsx', 'uniswap_ethereum_2021_12_14.xlsx', 'uniswap_ethereum_2021_12_28.xlsx', 'uniswap_ethereum_2021_12_16.xlsx', 'uniswap_ethereum_2021_12_27.xlsx', 'uniswap_ethereum_2021_12_17.xlsx', 'uniswap_ethereum_2021_12_26.xlsx', 'uniswap_ethereum_2021_12_15.xlsx', 'uniswap_ethereum_2021_12_19.xlsx', 'uniswap_ethereum_2021_12_18.xlsx', 'uniswap_ethereum_2021_12_20.xlsx', 'uniswap_ethereum_2021_12_21.xlsx', 'uniswap_ethereum_2021_12_22.xlsx'
# ...

# %%
df1 = pd.read_excel(dir_path+"/"+"uniswap_ethereum_2021_12_1.xlsx")
df1.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                                   ID  \
# 0  0x000064aa7e3a5ad714c9ad5a407d6431c34598462eaf...
# 1  0x0000dc3f62b01784a5d673a125a0a4686eacaeaf3d38...
# 2  0x0000eee5059a11f6a4fe7bc8beafc9a016a8f14b9d6c...
# 3  0x000141996c0bab9dc3ab43d76beda04d0026e75789d7...
# 4  0x00037d1610cb810bbe4e3807cb10a2a57460d0680498...
#
#                                       Transaction ID           Timestamp  \
# 0  0x000064aa7e3a5ad714c9ad5a407d6431c34598462eaf... 2021-12-01 22:17:59
# 1  0x0000dc3f62b01784a5d673a125a0a4686eacaeaf3d38... 2021-12-01 18:25:23
# 2  0x0000eee5059a11f6a4fe7bc8beafc9a016a8f14b9d6c... 2021-12-01 18:24:43
# 3  0x000141996c0bab9dc3ab43d76beda04d0026e75789d7... 2021-12-01 14:18:55
# 4  0x00037d1610cb810bbe4e3807cb10a2a57460d0680498... 2021-12-01 04:38:08
#
# ...

# %%
df1.tail()
# Out:
#                                                       ID  \
# 41076  0xfff76045c158d525dfc0de4701a4a5379cefeb324801...
# 41077  0xfff79a721076be9b5ef42ac030bc1a4664b8451af408...
# 41078  0xfff9ae833073ac322737a1ab190c16b5c4341add551f...
# 41079  0xfffa19ee0dd69e630232d504fc1c40fc9179a80dd3b7...
# 41080  0xfffe7316e9cbdb0f64f1521adbd9687054673e0491b7...
#
#                                           Transaction ID           Timestamp  \
# 41076  0xfff76045c158d525dfc0de4701a4a5379cefeb324801... 2021-12-01 07:18:36
# 41077  0xfff79a721076be9b5ef42ac030bc1a4664b8451af408... 2021-12-01 01:36:30
# 41078  0xfff9ae833073ac322737a1ab190c16b5c4341add551f... 2021-12-01 00:14:44
# 41079  0xfffa19ee0dd69e630232d504fc1c40fc9179a80dd3b7... 2021-12-01 18:39:59
# 41080  0xfffe7316e9cbdb0f64f1521adbd9687054673e0491b7... 2021-12-01 12:41:46
#
#        Timestamp (Unix)                                        Pool  \
# 41076        1638371916  0x5777d92f208679db4b9778590fa3cab3ac9e2168
# ...

# %%
files = res

# %%
df =df1
from tqdm import tqdm
for file in tqdm(files): 
    # combining multiple excel worksheets 
    # into single data frames
    df = pd.concat([df, pd.read_excel(dir_path+"/"+file)],
                   ignore_index=True, sort=False)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   3%|▎         | 1/31 [00:11<05:58, 11.94s/it]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   6%|▋         | 2/31 [00:24<05:50, 12.09s/it]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  10%|▉         | 3/31 [00:38<06:07, 13.11s/it]/usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ...

# %%
df_Eth_Dec2021 = df
df_Eth_Dec2021.tail()
# Out:
#                                                         ID  \
# 1318329  0xfffae2f0eaf220fc67cf555a228c6836f887c2a08340...
# 1318330  0xfffb7eb1f12e78e27b1bcbab4bc1ae6089845b6148c7...
# 1318331  0xfffb7eb1f12e78e27b1bcbab4bc1ae6089845b6148c7...
# 1318332  0xfffe6e013ee8aabe8dec80b0e71b2ba0dfddbf107767...
# 1318333  0xfffee8c60241f23ee66c5fcb44fe74895cdee9e69ddf...
#
#                                             Transaction ID  \
# 1318329  0xfffae2f0eaf220fc67cf555a228c6836f887c2a08340...
# 1318330  0xfffb7eb1f12e78e27b1bcbab4bc1ae6089845b6148c7...
# 1318331  0xfffb7eb1f12e78e27b1bcbab4bc1ae6089845b6148c7...
# 1318332  0xfffe6e013ee8aabe8dec80b0e71b2ba0dfddbf107767...
# 1318333  0xfffee8c60241f23ee66c5fcb44fe74895cdee9e69ddf...
#
#                   Timestamp  Timestamp (Unix)  \
# 1318329 2021-12-24 21:24:35        1640409875
# 1318330 2021-12-24 00:41:43        1640335303
# 1318331 2021-12-24 00:41:43        1640335303
# 1318332 2021-12-24 16:50:25        1640393425
# ...

# %%
df_Eth_Dec2021.to_csv("Eth_Dec2021.csv")

# %%
df_Eth_Dec2021 = pd.read_csv("Eth_Dec2021.csv")

# %%
Eth_Amount_Dec2021 = df_Eth_Dec2021[["Timestamp", "Amount USD (Excel)"]]

# %%
Eth_Amount_Dec2021.columns =['Timestamp', 'Amount_USD']
Eth_Amount_Dec2021
# Out:
#                    Timestamp     Amount_USD
# 0        2021-12-01 22:17:59   31220.047515
# 1        2021-12-01 18:25:23     473.435869
# 2        2021-12-01 18:24:43   40230.307315
# 3        2021-12-01 14:18:55  970837.383420
# 4        2021-12-01 04:38:08    2056.401245
# ...                      ...            ...
# 1318329  2021-12-24 21:24:35    5405.825961
# 1318330  2021-12-24 00:41:43     983.611151
# 1318331  2021-12-24 00:41:43     984.389335
# 1318332  2021-12-24 16:50:25    3193.092564
# 1318333  2021-12-24 02:42:07     100.000000
#
# [1318334 rows x 2 columns]

# %%
Eth_Amount_Dec2021['Timestamp']=pd.to_datetime(Eth_Amount_Dec2021['Timestamp'])
Eth_Amount_Dec2021.dtypes
# Out:
# <ipython-input-32-96ab04752b09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Eth_Amount_Dec2021['Timestamp']=pd.to_datetime(Eth_Amount_Dec2021['Timestamp'])
# Timestamp     datetime64[ns]
# Amount_USD           float64
# dtype: object

# %%
Eth_Amount_Dec2021=Eth_Amount_Dec2021.sort_values(by='Timestamp')
Eth_Amount_Dec2021
# Out:
#                  Timestamp     Amount_USD
# 50098  2021-12-01 00:00:16   31689.440744
# 65539  2021-12-01 00:00:16  227501.971021
# 37999  2021-12-01 00:00:16    4767.773640
# 65538  2021-12-01 00:00:16  227303.051327
# 4202   2021-12-01 00:00:16    2692.595290
# ...                    ...            ...
# 376158 2021-12-31 23:59:58    2535.041777
# 366362 2021-12-31 23:59:58     927.938648
# 371890 2021-12-31 23:59:58     144.362869
# 386364 2021-12-31 23:59:58   36468.531984
# 386365 2021-12-31 23:59:58   36428.474958
#
# [1318334 rows x 2 columns]

# %%
Eth_Amount_Dec2021.to_csv("Eth_Amount_Dec2021.csv")
